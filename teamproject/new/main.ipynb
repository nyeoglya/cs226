# %% [markdown]
# # 0. Set Up
# - 기본 분석: numpy, pandas, matplotlib, seaborn
# - 모델: scikit-learn, torch, tqdm, lightgbm, xgboost

# %%
# !pip install torch lightgbm xgboost

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn tqdm

# %% [markdown]
# # 1. Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data loading
original_train_labels = pd.read_csv("./data/train_labels.csv")
original_train_values = pd.read_csv("./data/train_values.csv")
original_test_values = pd.read_csv("./data/test_values.csv")

# %%
# data info
original_train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
#  10  roof_type                               260601 non-null  object
#  11  ground_floor_type                       260601 non-null  object
#  12  other_floor_type                        260601 non-null  object
#  13  position                                260601 non-null  object
#  14  plan_configuration                      260601 non-null  object
#  15  has_superstructure_adobe_mud            260601 non-null  int64
#  16  has_superstructure_mud_mortar_stone     260601 non-null  int64
#  17  has_superstructure_stone_flag           260601 non-null  int64
#  18  has_superstructure_cement_mortar_stone  260601 non-null  int64
#  19  has_superstructure_mud_mortar_brick     260601 non-null  int64
#  20  has_superstructure_cement_mortar_brick  260601 non-null  int64
#  21  has_superstructure_timber               260601 non-null  int64
#  22  has_superstructure_bamboo               260601 non-null  int64
#  23  has_superstructure_rc_non_engineered    260601 non-null  int64
#  24  has_superstructure_rc_engineered        260601 non-null  int64
#  25  has_superstructure_other                260601 non-null  int64
#  26  legal_ownership_status                  260601 non-null  object
#  27  count_families                          260601 non-null  int64
#  28  has_secondary_use                       260601 non-null  int64
#  29  has_secondary_use_agriculture           260601 non-null  int64
#  30  has_secondary_use_hotel                 260601 non-null  int64
#  31  has_secondary_use_rental                260601 non-null  int64
#  32  has_secondary_use_institution           260601 non-null  int64
#  33  has_secondary_use_school                260601 non-null  int64
#  34  has_secondary_use_industry              260601 non-null  int64
#  35  has_secondary_use_health_post           260601 non-null  int64
#  36  has_secondary_use_gov_office            260601 non-null  int64
#  37  has_secondary_use_use_police            260601 non-null  int64
#  38  has_secondary_use_other                 260601 non-null  int64
# dtypes: int64(31), object(8)
# memory usage: 77.5+ MB

# %%
# check null
original_train_values.isnull().sum()
# Out:
# building_id                               0
# geo_level_1_id                            0
# geo_level_2_id                            0
# geo_level_3_id                            0
# count_floors_pre_eq                       0
# age                                       0
# area_percentage                           0
# height_percentage                         0
# land_surface_condition                    0
# foundation_type                           0
# roof_type                                 0
# ground_floor_type                         0
# other_floor_type                          0
# position                                  0
# plan_configuration                        0
# has_superstructure_adobe_mud              0
# has_superstructure_mud_mortar_stone       0
# has_superstructure_stone_flag             0
# has_superstructure_cement_mortar_stone    0
# has_superstructure_mud_mortar_brick       0
# has_superstructure_cement_mortar_brick    0
# has_superstructure_timber                 0
# has_superstructure_bamboo                 0
# has_superstructure_rc_non_engineered      0
# has_superstructure_rc_engineered          0
# has_superstructure_other                  0
# legal_ownership_status                    0
# count_families                            0
# has_secondary_use                         0
# has_secondary_use_agriculture             0
# has_secondary_use_hotel                   0
# has_secondary_use_rental                  0
# has_secondary_use_institution             0
# has_secondary_use_school                  0
# has_secondary_use_industry                0
# has_secondary_use_health_post             0
# has_secondary_use_gov_office              0
# has_secondary_use_use_police              0
# has_secondary_use_other                   0
# dtype: int64

# %%
# damage_grade distribution (class imbalance)
sns.countplot(x="damage_grade", data=original_train_labels)
plt.title("damage drade distribution")
plt.show()

# %%
# data count
original_train_values['has_secondary_use_use_police'].value_counts()

# %%
# detailed histogram (height_percentage)
plt.figure(figsize=(18,9))
sns.countplot(x=np.clip(original_train_values["area_percentage"],0,30), hue=original_train_labels["damage_grade"])
plt.ylabel("frequency")
plt.xlabel("height Percentage")
plt.xticks(rotation=90)
plt.title("height percentage histograms")
plt.legend(["damage_grade = 1","damage_grade = 2","damage_grade = 3"])
plt.show()

# %% [markdown]
# # 2. Selecting Columns
# - train a lightGBM model
# - perform a hyperparameter tuning
# - TODO: 중요도가 낮은 것부터 하나씩 지워나가며 성능 변화를 관찰하기

# %%
import pickle
from model import LightGBM

# %% [markdown]
# ## 2-1. Basic Model

# %%
# categorical cols definition
original_categorical_cols = [
    "geo_level_1_id", 
    "geo_level_2_id",
    "geo_level_3_id",
    "foundation_type",
    "roof_type",
    "ground_floor_type",
    "land_surface_condition",
    "other_floor_type",
    "position",
    "plan_configuration",
    "legal_ownership_status",
]

# %%
# data merge + define model
original_train_merge = original_train_values.merge(original_train_labels, on="building_id", how="left")
lgb_original = LightGBM(df=original_train_merge, target_col="damage_grade")
lgb_original.encoding(categorical_cols=original_categorical_cols)
lgb_original.kfold(n_splits=5)

# %%
# check validity (not necessary)
original_train_columns = lgb_original.X.columns.to_list()
"building_id" in original_train_columns, len(original_train_columns)
# Out:
# (False, 38)

# %%
# train the model
lgb_original.train()
# Out:
# 0it [00:00, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [131]	valid_0's multi_logloss: 0.56082
# 1it [00:22, 22.56s/it]
# [Fold 0] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [146]	valid_0's multi_logloss: 0.560175
# 2it [00:40, 20.02s/it]
# [Fold 1] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [138]	valid_0's multi_logloss: 0.557229
# 3it [00:58, 19.00s/it]
# [Fold 2] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [140]	valid_0's multi_logloss: 0.562868
# 4it [01:16, 18.46s/it]
# [Fold 3] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [123]	valid_0's multi_logloss: 0.562515
# 5it [01:32, 18.58s/it]
# [Fold 4] done.

# %%
# evaluate the model
lgb_original.eval()
# Out:
# LightGBM Small Model CV Micro F1: 0.75014
# 0.7501429388221841

# %%
# save models
with open("lgb_original.pkl", "wb") as f:
    pickle.dump(lgb_original, f)

# %%
# load models
with open("lgb_original.pkl", "rb") as f:
    lgb_original = pickle.load(f)

print(f"모델 개수: {len(lgb_original.models)}")
print(f"모델 타입: {type(lgb_original.models[0])}")
# Out:
# 모델 개수: 5
# 모델 타입: <class 'lightgbm.sklearn.LGBMClassifier'>

# %% [markdown]
# ## 2-2. Column Importance Measure

# %%
# importance measure on each features
importances = lgb_original.models[0].feature_importances_
cols = lgb_original.X.columns

featimp_df = pd.DataFrame({
    "feature": cols,
    "importance": importances
}).sort_values("importance", ascending=False)

# %%
low_K = 10
print(featimp_df.head(len(featimp_df)-low_K))
# Out:
#                                    feature  importance
# 2                           geo_level_3_id       24941
# 1                           geo_level_2_id       11057
# 4                                      age        2890
# 5                          area_percentage        2016
# 0                           geo_level_1_id        1520
# 6                        height_percentage        1118
# 26                          count_families         781
# 9                                roof_type         644
# 12                                position         495
# 3                      count_floors_pre_eq         448
# 15     has_superstructure_mud_mortar_stone         407
# 19  has_superstructure_cement_mortar_brick         373
# 8                          foundation_type         367
# 11                        other_floor_type         357
# 7                   land_surface_condition         331
# 10                       ground_floor_type         312
# 27                       has_secondary_use         251
# 18     has_superstructure_mud_mortar_brick         225
# 17  has_superstructure_cement_mortar_stone         198
# 20               has_superstructure_timber         166
# 13                      plan_configuration         145
# 14            has_superstructure_adobe_mud         130
# 23        has_superstructure_rc_engineered         108
# 25                  legal_ownership_status         107
# 28           has_secondary_use_agriculture          90
# 16           has_superstructure_stone_flag          90
# 24                has_superstructure_other          90
# 22    has_superstructure_rc_non_engineered          70

# %%
print(featimp_df.tail(low_K))
# Out:
#                           feature  importance
# 29        has_secondary_use_hotel          65
# 21      has_superstructure_bamboo          57
# 30       has_secondary_use_rental          44
# 37        has_secondary_use_other          17
# 33     has_secondary_use_industry           1
# 31  has_secondary_use_institution           0
# 32       has_secondary_use_school           0
# 34  has_secondary_use_health_post           0
# 35   has_secondary_use_gov_office           0
# 36   has_secondary_use_use_police           0

# %% [markdown]
# ## 2-3. Column Selection Experiment
# - omitted on the current pipeline

# %%
# select columns
top_col = featimp_df.head(len(featimp_df)-low_K)['feature'].tolist()
top_col.append("damage_grade")

# %%
top_train_merge = original_train_merge.copy()
top_train_merge["height_percentage"] = np.clip(top_train_merge["height_percentage"],0,11)
# top_train_merge["area_percentage"] = np.clip(original_train_values["area_percentage"],0,30)

# %%
# define a new model
top_categorical_cols = list(set(top_col).intersection(original_categorical_cols))
lgb_top = LightGBM(df=top_train_merge[top_col], target_col="damage_grade")
lgb_top.encoding(categorical_cols=top_categorical_cols)
lgb_top.kfold(n_splits=5)

# %%
lgb_top.train()
# Out:
# 0it [00:00, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	valid_0's multi_logloss: 0.561004
# 1it [00:17, 17.16s/it]
# [Fold 0] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	valid_0's multi_logloss: 0.559979
# 2it [00:33, 16.75s/it]
# [Fold 1] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	valid_0's multi_logloss: 0.557605
# 3it [00:52, 17.55s/it]
# [Fold 2] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [148]	valid_0's multi_logloss: 0.56314
# 4it [01:10, 18.04s/it]
# [Fold 3] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	valid_0's multi_logloss: 0.562342
# 5it [01:27, 17.42s/it]
# [Fold 4] done.

# %%
lgb_top.eval()
# Out:
# LightGBM Small Model CV Micro F1: 0.75024
# 0.7502350336337926

# %%
with open("lgb_top.pkl", "wb") as f:
    pickle.dump(lgb_original, f)

# %% [markdown]
# # 3. Data Preprocessing
# - Low-dim mapping
# - columns add
# - colum transformer

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import pandas as pd
from sklearn.model_selection import train_test_split

from preprocess import GeoHierDataset
from preprocess import GeoEncoderWithHead
from preprocess import hier_train, hier_eval, hier_embed

# %%
# 이 파트는 선택적임
try:
    top_col.remove('damage_grade')
except:
    pass
top_col.append('building_id')
modified_train_values = original_train_values[top_col]
modified_train_labels = original_train_labels['damage_grade'] - 1
modified_test_values = original_test_values[top_col]

# %% [markdown]
# ## 3-1. Low-dim Mapping

# %%
X_train, X_test, y_train, y_test = train_test_split(original_train_values, original_train_labels, test_size=0.2, random_state=42)

y_train_idx = y_train['damage_grade'] - 1
y_test_idx  = y_test['damage_grade'] - 1

y_train_idx = y_train_idx.rename("damage_grade")
y_test_idx  = y_test_idx.rename("damage_grade")

att_train_dataset = pd.concat([X_train, y_train_idx], axis=1)
att_val_dataset   = pd.concat([X_test,  y_test_idx],  axis=1)

train_dataset = GeoHierDataset(att_train_dataset, label_col="damage_grade")
val_dataset = GeoHierDataset(att_val_dataset, label_col="damage_grade")

train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=1024, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 카테고리 개수
n1 = att_train_dataset["geo_level_1_id"].max() + 1
n2 = att_train_dataset["geo_level_2_id"].max() + 1
n3 = att_train_dataset["geo_level_3_id"].max() + 1
n_classes = att_train_dataset["damage_grade"].nunique()  # 예: 3

model = GeoEncoderWithHead(
    n1=n1, n2=n2, n3=n3,
    n_classes=n_classes,
    d=32,
    geo_dim=32,
    n_heads=1,
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
# 실제 학습
epochs = 10
for epoch in range(1, epochs+1):
    train_loss, train_acc = hier_train(model, train_loader, optimizer, criterion, device)
    val_loss, val_acc = hier_eval(model, val_loader, criterion, device)
    print(f"[Epoch {epoch:02d}] "
          f"Train loss: {train_loss:.4f}, acc: {train_acc:.4f} | "
          f"Val loss: {val_loss:.4f}, acc: {val_acc:.4f}")

# %%
torch.save(model.state_dict(), "geo_encoder_best_weights.pth")
print(f"모델 가중치를 저장했습니다.")
# Out:
# 모델 가중치를 저장했습니다.

# %%
loaded_model = GeoEncoderWithHead(
    n1=n1, n2=n2, n3=n3,
    n_classes=n_classes,
    d=32,
    geo_dim=32,
    n_heads=1,
).to(device)

loaded_model.load_state_dict(torch.load("geo_encoder_best_weights.pth"))
loaded_model.eval()

print("저장된 모델 가중치 로드 완료.")
# Out:
# 저장된 모델 가중치 로드 완료.

# %%
train_values_embedded = hier_embed(original_train_values, loaded_model, device)
test_values_embedded = hier_embed(original_test_values, loaded_model, device)
train_labels_embedded = original_train_labels

# train_values_embedded["height_percentage"] = np.clip(train_values_embedded["height_percentage"],0,11)
# test_values_embedded["height_percentage"] = np.clip(test_values_embedded["height_percentage"],0,11)

print("dataset shape with embedding columns:")
print("Train:", train_values_embedded.shape)
print("Test:", test_values_embedded.shape)
# Out:
# Extracting: 100%|██████████| 255/255 [00:18<00:00, 13.71it/s]
# Extracting: 100%|██████████| 85/85 [00:06<00:00, 13.98it/s]
# dataset shape with embedding columns:
# Train: (260601, 68)
# Test: (86868, 68)

# %% [markdown]
# ## 3-2. Auto Encoder

# %%
from preprocess.auto import GeoAutoEncoder

# %%
df_train_geo = original_train_values[['geo_level_3_id', 'geo_level_2_id', 'geo_level_1_id']]
df_test_geo = original_test_values[['geo_level_3_id', 'geo_level_2_id', 'geo_level_1_id']]

df_combined = pd.concat([df_train_geo, df_test_geo], ignore_index=True)

# %%
autoencoder = GeoAutoEncoder(
    latent_dim=16,
    epochs=10,
    batch_size=1024,
    device='cpu' # TODO: GPU 사용하기
)

# 학습
print("학습 시작")
autoencoder.fit(df_combined)
# Out:
# 학습 시작
# Detected sizes: L1=31, L2=1428, L3=12568
# Training on cpu for 10 epochs...
# Epoch 1: Avg Loss = 12.1276
# Epoch 2: Avg Loss = 2.7655
# Epoch 3: Avg Loss = 0.9652
# Epoch 4: Avg Loss = 0.5165
# Epoch 5: Avg Loss = 0.3315
# Epoch 6: Avg Loss = 0.2321
# Epoch 7: Avg Loss = 0.1706
# Epoch 8: Avg Loss = 0.1293
# Epoch 9: Avg Loss = 0.0996
# Epoch 10: Avg Loss = 0.0784
# GeoAutoEncoder(batch_size=1024, device='cpu')

# %%
autoencoder.save("models/geo_ae_model.pth")
# Out:
# Model saved to models/geo_ae_model.pth

# %%
loaded_ae = GeoAutoEncoder().load("models/geo_ae_model.pth")

# %%
print("임베딩 추출")
train_embeddings = autoencoder.transform(original_train_values)
test_embeddings = autoencoder.transform(original_test_values)
# Out:
# 임베딩 추출
# Extracting Embeddings: 100%|██████████| 128/128 [00:01<00:00, 101.48it/s]
# Extracting Embeddings: 100%|██████████| 43/43 [00:00<00:00, 77.40it/s]

# %%
print(f"추출된 임베딩 형태: {train_embeddings.shape}")
print(f"추출된 임베딩 형태: {test_embeddings.shape}")
# Out:
# 추출된 임베딩 형태: (260601, 16)
# 추출된 임베딩 형태: (86868, 16)

# %%
import pandas as pd
EMBEDDING_DIM = train_embeddings.shape[1]
embed_cols = [f"geo_emb2_{i}" for i in range(EMBEDDING_DIM)]

train_embeddings_df = pd.DataFrame(
    train_embeddings,
    columns=embed_cols
)
test_embeddings_df = pd.DataFrame(
    test_embeddings,
    columns=embed_cols
)

# 결과 확인
print("훈련 임베딩 DataFrame 생성 완료:")
print(f"차원: {train_embeddings_df.shape}")
print(train_embeddings_df.head())

print("테스트 임베딩 DataFrame 생성 완료:")
print(f"차원: {test_embeddings_df.shape}")
print(test_embeddings_df.head())
# Out:
# 훈련 임베딩 DataFrame 생성 완료:
# 차원: (260601, 16)
#    geo_emb2_0  geo_emb2_1  geo_emb2_2  geo_emb2_3  geo_emb2_4  geo_emb2_5  \
# 0    6.828994   21.101688    8.474803   14.649942   21.070877   47.433128
# 1   37.395012   30.637888   18.684908   12.039928   37.425091   21.644316
# 2   35.091362   15.104170   52.822598   48.692177    0.657782   42.670250
# 3   28.726034   28.856403   38.410576   11.262142   46.244617   40.991688
# 4    1.030481   12.293140   47.031216   47.473938    4.417999    6.388467
#
#    geo_emb2_6  geo_emb2_7  geo_emb2_8  geo_emb2_9  geo_emb2_10  geo_emb2_11  \
# 0         0.0   29.018898   59.155689   48.986164          0.0     0.632905
# 1         0.0   37.616325   27.948729   44.663967          0.0     1.550905
# 2         0.0   16.617846   38.701488   57.741741          0.0    29.273264
# 3         0.0    0.000000   52.789894   45.588905          0.0    20.769320
# 4         0.0   39.977135   54.841244   11.737732          0.0    46.425812
#
#    geo_emb2_12  geo_emb2_13  geo_emb2_14  geo_emb2_15
# 0    45.009613    37.701000          0.0    25.504128
# 1    14.352452    25.110588          0.0    65.580338
# 2     4.414596    58.481236          0.0     7.209785
# 3    24.839901     0.000000          0.0    36.607803
# 4     5.568959    31.887718          0.0    45.659000
# 테스트 임베딩 DataFrame 생성 완료:
# 차원: (86868, 16)
#    geo_emb2_0  geo_emb2_1  geo_emb2_2  geo_emb2_3  geo_emb2_4  geo_emb2_5  \
# 0   38.242458   49.946301   60.958111   41.993664   23.115747    6.826780
# 1   22.859892   28.561001    9.105667   63.984276   33.744278   41.412643
# 2   15.588364   18.864042   33.646179   33.825310   29.473751   30.338293
# 3  101.717781   65.493362   62.567585   42.855370   63.921665   43.059174
# 4   54.311012   64.713959   11.762283   33.771648   24.425785   17.169069
#
#    geo_emb2_6  geo_emb2_7  geo_emb2_8  geo_emb2_9  geo_emb2_10  geo_emb2_11  \
# 0         0.0   19.195095    9.896124   16.387190          0.0    30.173679
# 1         0.0   21.782589   44.167526   33.331028          0.0     6.984731
# 2         0.0    3.445972   59.068054   22.531986          0.0    40.895451
# 3         0.0   64.883804   32.616116   54.418461          0.0    34.573963
# 4         0.0   25.522579   46.917503   18.011576          0.0     2.173956
#
#    geo_emb2_12  geo_emb2_13  geo_emb2_14  geo_emb2_15
# 0    37.927086    33.401890          0.0    21.750597
# 1    13.730006    45.646618          0.0    59.305618
# 2    28.670450     6.862791          0.0    24.780664
# 3     8.716598    62.393013          0.0    46.827839
# 4    35.367664    22.650282          0.0    19.989212

# %% [markdown]
# ## 3-3. Hierarical Model by using Metric Learning

# %%
from preprocess.triplet import GeoTripletDataset, GeoMetricEncoder, train_metric, metric_embed

# %%
num_l3 = df_combined['geo_level_3_id'].max() + 1
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
trained_model = train_metric(df_combined, num_l3=num_l3, epochs=6, device=device)
# Out:
# Epoch 1: 100%|██████████| 1358/1358 [00:39<00:00, 34.41it/s]
# Epoch 1 Avg Loss: 0.4948
# Epoch 2: 100%|██████████| 1358/1358 [00:38<00:00, 34.93it/s]
# Epoch 2 Avg Loss: 0.1717
# Epoch 3: 100%|██████████| 1358/1358 [00:40<00:00, 33.71it/s]
# Epoch 3 Avg Loss: 0.1132
# Epoch 4: 100%|██████████| 1358/1358 [00:51<00:00, 26.54it/s]
# Epoch 4 Avg Loss: 0.0931
# Epoch 5: 100%|██████████| 1358/1358 [00:48<00:00, 28.10it/s]
# Epoch 5 Avg Loss: 0.0840
# Epoch 6: 100%|██████████| 1358/1358 [00:39<00:00, 34.59it/s]
# Epoch 6 Avg Loss: 0.0770

# %%
import torch
from pathlib import Path

MODEL_DIR = Path('./models') 
MODEL_DIR.mkdir(exist_ok=True) # 폴더가 없으면 생성

MODEL_FILENAME = f'geo_metric_encoder_e6_dim{trained_model.projection[-1].out_features}.pth'
SAVE_PATH = MODEL_DIR / MODEL_FILENAME

torch.save(trained_model.state_dict(), SAVE_PATH)

# %%
import torch
from pathlib import Path

# 로드 설정
MODEL_DIR = Path('./models')
MODEL_FILENAME = 'geo_metric_encoder_e6_dim32.pth'
SAVE_PATH = MODEL_DIR / MODEL_FILENAME 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
map_device = device 

loaded_model = GeoMetricEncoder(num_l3=num_l3, embedding_dim=32) 
state_dict = torch.load(SAVE_PATH, map_location=map_device)
loaded_model.load_state_dict(state_dict)
loaded_model.eval()

print(f"모델 가중치 로드 완료. 모델은 현재 {map_device}에 있습니다.")
# Out:
# 모델 가중치 로드 완료. 모델은 현재 cpu에 있습니다.

# %%
unique_l3 = df_combined['geo_level_3_id'].unique()
vector_map = metric_embed(loaded_model, unique_l3, device)

# %%
vector_map.shape
# Out:
# (11861, 32)

# %% [markdown]
# ## 3.4 Data Combining

# %%
import pandas as pd
import numpy as np

EMBEDDING_DIM = vector_map.shape[1]
embed_cols = [f"geo_emb_{i}" for i in range(EMBEDDING_DIM)]

# Lookup table DataFrame (Geo L3 ID와 Vector 연결)
vector_map_df = pd.DataFrame(vector_map, columns=embed_cols)
vector_map_df['geo_level_3_id'] = unique_l3
# 이 DataFrame은 각 Geo L3 ID에 대한 고유한 임베딩 벡터를 포함합니다.

def merge_embeddings_and_clean(df_input, map_df):
    """원본 DataFrame에 임베딩을 병합하고, 원래의 Geo ID 컬럼을 삭제합니다."""
    
    # 1. Geo Level 3 ID를 기준으로 임베딩 벡터를 병합 (how='left'로 행 순서 유지)
    df_merged = df_input.merge(
        map_df, 
        on='geo_level_3_id', 
        how='left'
    )
    
    # 2. 삭제할 컬럼 정의 (원본 Geo ID)
    cols_to_drop = [
        'geo_level_1_id', 
        'geo_level_2_id', 
        'geo_level_3_id'
    ]
    
    # 3. 원본 Geo ID 컬럼들을 삭제하고 반환
    # errors='ignore'를 사용하여 이미 제거되었을 경우 오류 방지
    df_cleaned = df_merged.drop(columns=cols_to_drop, errors='ignore')
    
    return df_cleaned

train_features_embedded = merge_embeddings_and_clean(original_train_values, vector_map_df)
test_features_embedded = merge_embeddings_and_clean(original_test_values, vector_map_df)

# 3. 결과 출력
print("훈련 데이터 피처 (Geo ID 제거 후 임베딩 추가):")
print(f"새로운 형태: {train_features_embedded.shape}")
print(train_features_embedded[[col for col in train_features_embedded.columns if 'geo_emb' in col]].head())

print("테스트 데이터 피처 (Geo ID 제거 후 임베딩 추가):")
print(f"새로운 형태: {test_features_embedded.shape}")
print(test_features_embedded[[col for col in test_features_embedded.columns if 'geo_emb' in col]].head())
# Out:
# 훈련 데이터 피처 (Geo ID 제거 후 임베딩 추가):
# 새로운 형태: (260601, 68)
#    geo_emb_0  geo_emb_1  geo_emb_2  geo_emb_3  geo_emb_4  geo_emb_5  \
# 0   0.052421  -0.226410   0.014361   0.077549   0.031915   0.109300
# 1  -0.304638   0.076604   0.085841   0.021475  -0.286006  -0.226572
# 2   0.196524  -0.397095  -0.125743  -0.124669   0.209139   0.008871
# 3  -0.063439   0.203958   0.061428   0.252623  -0.127502   0.186127
# 4   0.146469  -0.358771  -0.043425  -0.032648   0.146772   0.075012
#
#    geo_emb_6  geo_emb_7  geo_emb_8  geo_emb_9  ...  geo_emb_22  geo_emb_23  \
# 0  -0.072760  -0.186794  -0.281290   0.367311  ...    0.116633    0.286511
# 1  -0.026238  -0.070000  -0.111879  -0.198614  ...    0.066415    0.200670
# 2   0.083708  -0.244732  -0.152054   0.338706  ...    0.015785    0.027957
# 3  -0.110770   0.117965  -0.099924   0.039697  ...    0.011037    0.245822
# 4  -0.012329  -0.246072  -0.243154   0.417256  ...    0.096162    0.168784
#
#    geo_emb_24  geo_emb_25  geo_emb_26  geo_emb_27  geo_emb_28  geo_emb_29  \
# 0   -0.165332   -0.103843    0.270316   -0.173117   -0.145060    0.037938
# 1    0.232124   -0.040514   -0.026072    0.139313   -0.139064   -0.312466
# 2   -0.091391   -0.296943    0.234235   -0.293910   -0.047331    0.200591
# 3   -0.082729    0.264544    0.004784    0.068422   -0.138084   -0.086232
# 4   -0.172808   -0.229262    0.295248   -0.257442   -0.085643    0.141855
#
#    geo_emb_30  geo_emb_31
# 0   -0.040242   -0.105006
# 1   -0.176639   -0.064885
# 2   -0.065915   -0.090487
# 3    0.129720    0.044394
# 4   -0.065283   -0.117982
#
# [5 rows x 32 columns]
# 테스트 데이터 피처 (Geo ID 제거 후 임베딩 추가):
# 새로운 형태: (86868, 68)
#    geo_emb_0  geo_emb_1  geo_emb_2  geo_emb_3  geo_emb_4  geo_emb_5  \
# 0   0.254690  -0.150948  -0.057865   0.097942   0.208335   0.288007
# 1   0.087781   0.000870  -0.164485  -0.112314   0.091522  -0.080855
# 2   0.144609   0.214438   0.115288   0.094514   0.128704   0.272533
# 3  -0.104457  -0.029607   0.280877  -0.072330  -0.032950  -0.039211
# 4  -0.030578  -0.247282  -0.196033   0.052261  -0.074286  -0.079282
#
#    geo_emb_6  geo_emb_7  geo_emb_8  geo_emb_9  ...  geo_emb_22  geo_emb_23  \
# 0  -0.037193  -0.036087  -0.119077   0.388528  ...    0.009814    0.092103
# 1   0.177941   0.056705   0.178237  -0.176946  ...   -0.183944   -0.231928
# 2  -0.142682   0.230428   0.170614   0.046839  ...    0.039633   -0.166072
# 3  -0.224512  -0.071638  -0.039295   0.097558  ...    0.293951   -0.006299
# 4   0.146018  -0.231017  -0.295915   0.154733  ...   -0.091232    0.341125
#
#    geo_emb_24  geo_emb_25  geo_emb_26  geo_emb_27  geo_emb_28  geo_emb_29  \
# 0   -0.290121    0.031312    0.189580   -0.208876   -0.032485    0.245110
# 1    0.159521   -0.046407   -0.147435   -0.050252    0.035424    0.099049
# 2   -0.292749    0.280002   -0.071605    0.118322    0.225223    0.148766
# 3   -0.198012   -0.059502    0.108639    0.160536    0.213317   -0.092871
# 4    0.186295   -0.195203    0.171716   -0.257510   -0.374662   -0.051559
#
#    geo_emb_30  geo_emb_31
# 0    0.148066    0.001888
# 1    0.052062    0.085087
# 2    0.197084    0.081035
# 3   -0.171340   -0.138520
# 4   -0.066164   -0.053967
#
# [5 rows x 32 columns]

# %%
# 순서 보장 가정 하에 안전하게 결합하는 방법
test_features_with_embeddings = pd.concat(
    [test_features_embedded.reset_index(drop=True), test_embeddings_df], 
    axis=1
)
test_features_with_embeddings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86868 entries, 0 to 86867
# Data columns (total 84 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   building_id                             86868 non-null  int64
#  1   count_floors_pre_eq                     86868 non-null  int64
#  2   age                                     86868 non-null  int64
#  3   area_percentage                         86868 non-null  int64
#  4   height_percentage                       86868 non-null  int64
#  5   land_surface_condition                  86868 non-null  object
#  6   foundation_type                         86868 non-null  object
#  7   roof_type                               86868 non-null  object
#  8   ground_floor_type                       86868 non-null  object
#  9   other_floor_type                        86868 non-null  object
#  10  position                                86868 non-null  object
#  11  plan_configuration                      86868 non-null  object
#  12  has_superstructure_adobe_mud            86868 non-null  int64
#  13  has_superstructure_mud_mortar_stone     86868 non-null  int64
#  14  has_superstructure_stone_flag           86868 non-null  int64
#  15  has_superstructure_cement_mortar_stone  86868 non-null  int64
#  16  has_superstructure_mud_mortar_brick     86868 non-null  int64
#  17  has_superstructure_cement_mortar_brick  86868 non-null  int64
#  18  has_superstructure_timber               86868 non-null  int64
#  19  has_superstructure_bamboo               86868 non-null  int64
#  20  has_superstructure_rc_non_engineered    86868 non-null  int64
#  21  has_superstructure_rc_engineered        86868 non-null  int64
#  22  has_superstructure_other                86868 non-null  int64
#  23  legal_ownership_status                  86868 non-null  object
#  24  count_families                          86868 non-null  int64
#  25  has_secondary_use                       86868 non-null  int64
#  26  has_secondary_use_agriculture           86868 non-null  int64
#  27  has_secondary_use_hotel                 86868 non-null  int64
#  28  has_secondary_use_rental                86868 non-null  int64
#  29  has_secondary_use_institution           86868 non-null  int64
#  30  has_secondary_use_school                86868 non-null  int64
#  31  has_secondary_use_industry              86868 non-null  int64
#  32  has_secondary_use_health_post           86868 non-null  int64
#  33  has_secondary_use_gov_office            86868 non-null  int64
#  34  has_secondary_use_use_police            86868 non-null  int64
#  35  has_secondary_use_other                 86868 non-null  int64
#  36  geo_emb_0                               86868 non-null  float32
#  37  geo_emb_1                               86868 non-null  float32
#  38  geo_emb_2                               86868 non-null  float32
#  39  geo_emb_3                               86868 non-null  float32
#  40  geo_emb_4                               86868 non-null  float32
#  41  geo_emb_5                               86868 non-null  float32
#  42  geo_emb_6                               86868 non-null  float32
#  43  geo_emb_7                               86868 non-null  float32
#  44  geo_emb_8                               86868 non-null  float32
#  45  geo_emb_9                               86868 non-null  float32
#  46  geo_emb_10                              86868 non-null  float32
#  47  geo_emb_11                              86868 non-null  float32
#  48  geo_emb_12                              86868 non-null  float32
#  49  geo_emb_13                              86868 non-null  float32
#  50  geo_emb_14                              86868 non-null  float32
#  51  geo_emb_15                              86868 non-null  float32
#  52  geo_emb_16                              86868 non-null  float32
#  53  geo_emb_17                              86868 non-null  float32
#  54  geo_emb_18                              86868 non-null  float32
#  55  geo_emb_19                              86868 non-null  float32
#  56  geo_emb_20                              86868 non-null  float32
#  57  geo_emb_21                              86868 non-null  float32
#  58  geo_emb_22                              86868 non-null  float32
#  59  geo_emb_23                              86868 non-null  float32
#  60  geo_emb_24                              86868 non-null  float32
#  61  geo_emb_25                              86868 non-null  float32
#  62  geo_emb_26                              86868 non-null  float32
#  63  geo_emb_27                              86868 non-null  float32
#  64  geo_emb_28                              86868 non-null  float32
#  65  geo_emb_29                              86868 non-null  float32
#  66  geo_emb_30                              86868 non-null  float32
#  67  geo_emb_31                              86868 non-null  float32
#  68  geo_emb2_0                              86868 non-null  float32
#  69  geo_emb2_1                              86868 non-null  float32
#  70  geo_emb2_2                              86868 non-null  float32
#  71  geo_emb2_3                              86868 non-null  float32
#  72  geo_emb2_4                              86868 non-null  float32
#  73  geo_emb2_5                              86868 non-null  float32
#  74  geo_emb2_6                              86868 non-null  float32
#  75  geo_emb2_7                              86868 non-null  float32
#  76  geo_emb2_8                              86868 non-null  float32
#  77  geo_emb2_9                              86868 non-null  float32
#  78  geo_emb2_10                             86868 non-null  float32
#  79  geo_emb2_11                             86868 non-null  float32
#  80  geo_emb2_12                             86868 non-null  float32
#  81  geo_emb2_13                             86868 non-null  float32
#  82  geo_emb2_14                             86868 non-null  float32
#  83  geo_emb2_15                             86868 non-null  float32
# dtypes: float32(48), int64(28), object(8)
# memory usage: 39.8+ MB

# %%
# 순서 보장 가정 하에 안전하게 결합하는 방법
train_features_with_embeddings = pd.concat(
    [train_features_embedded.reset_index(drop=True), train_embeddings_df], 
    axis=1
)
train_features_with_embeddings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 84 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   count_floors_pre_eq                     260601 non-null  int64
#  2   age                                     260601 non-null  int64
#  3   area_percentage                         260601 non-null  int64
#  4   height_percentage                       260601 non-null  int64
#  5   land_surface_condition                  260601 non-null  object
#  6   foundation_type                         260601 non-null  object
#  7   roof_type                               260601 non-null  object
#  8   ground_floor_type                       260601 non-null  object
#  9   other_floor_type                        260601 non-null  object
#  10  position                                260601 non-null  object
#  11  plan_configuration                      260601 non-null  object
#  12  has_superstructure_adobe_mud            260601 non-null  int64
#  13  has_superstructure_mud_mortar_stone     260601 non-null  int64
#  14  has_superstructure_stone_flag           260601 non-null  int64
#  15  has_superstructure_cement_mortar_stone  260601 non-null  int64
#  16  has_superstructure_mud_mortar_brick     260601 non-null  int64
#  17  has_superstructure_cement_mortar_brick  260601 non-null  int64
#  18  has_superstructure_timber               260601 non-null  int64
#  19  has_superstructure_bamboo               260601 non-null  int64
#  20  has_superstructure_rc_non_engineered    260601 non-null  int64
#  21  has_superstructure_rc_engineered        260601 non-null  int64
#  22  has_superstructure_other                260601 non-null  int64
#  23  legal_ownership_status                  260601 non-null  object
#  24  count_families                          260601 non-null  int64
#  25  has_secondary_use                       260601 non-null  int64
#  26  has_secondary_use_agriculture           260601 non-null  int64
#  27  has_secondary_use_hotel                 260601 non-null  int64
#  28  has_secondary_use_rental                260601 non-null  int64
#  29  has_secondary_use_institution           260601 non-null  int64
#  30  has_secondary_use_school                260601 non-null  int64
#  31  has_secondary_use_industry              260601 non-null  int64
#  32  has_secondary_use_health_post           260601 non-null  int64
#  33  has_secondary_use_gov_office            260601 non-null  int64
#  34  has_secondary_use_use_police            260601 non-null  int64
#  35  has_secondary_use_other                 260601 non-null  int64
#  36  geo_emb_0                               260601 non-null  float32
#  37  geo_emb_1                               260601 non-null  float32
#  38  geo_emb_2                               260601 non-null  float32
#  39  geo_emb_3                               260601 non-null  float32
#  40  geo_emb_4                               260601 non-null  float32
#  41  geo_emb_5                               260601 non-null  float32
#  42  geo_emb_6                               260601 non-null  float32
#  43  geo_emb_7                               260601 non-null  float32
#  44  geo_emb_8                               260601 non-null  float32
#  45  geo_emb_9                               260601 non-null  float32
#  46  geo_emb_10                              260601 non-null  float32
#  47  geo_emb_11                              260601 non-null  float32
#  48  geo_emb_12                              260601 non-null  float32
#  49  geo_emb_13                              260601 non-null  float32
#  50  geo_emb_14                              260601 non-null  float32
#  51  geo_emb_15                              260601 non-null  float32
#  52  geo_emb_16                              260601 non-null  float32
#  53  geo_emb_17                              260601 non-null  float32
#  54  geo_emb_18                              260601 non-null  float32
#  55  geo_emb_19                              260601 non-null  float32
#  56  geo_emb_20                              260601 non-null  float32
#  57  geo_emb_21                              260601 non-null  float32
#  58  geo_emb_22                              260601 non-null  float32
#  59  geo_emb_23                              260601 non-null  float32
#  60  geo_emb_24                              260601 non-null  float32
#  61  geo_emb_25                              260601 non-null  float32
#  62  geo_emb_26                              260601 non-null  float32
#  63  geo_emb_27                              260601 non-null  float32
#  64  geo_emb_28                              260601 non-null  float32
#  65  geo_emb_29                              260601 non-null  float32
#  66  geo_emb_30                              260601 non-null  float32
#  67  geo_emb_31                              260601 non-null  float32
#  68  geo_emb2_0                              260601 non-null  float32
#  69  geo_emb2_1                              260601 non-null  float32
#  70  geo_emb2_2                              260601 non-null  float32
#  71  geo_emb2_3                              260601 non-null  float32
#  72  geo_emb2_4                              260601 non-null  float32
#  73  geo_emb2_5                              260601 non-null  float32
#  74  geo_emb2_6                              260601 non-null  float32
#  75  geo_emb2_7                              260601 non-null  float32
#  76  geo_emb2_8                              260601 non-null  float32
#  77  geo_emb2_9                              260601 non-null  float32
#  78  geo_emb2_10                             260601 non-null  float32
#  79  geo_emb2_11                             260601 non-null  float32
#  80  geo_emb2_12                             260601 non-null  float32
#  81  geo_emb2_13                             260601 non-null  float32
#  82  geo_emb2_14                             260601 non-null  float32
#  83  geo_emb2_15                             260601 non-null  float32
# dtypes: float32(48), int64(28), object(8)
# memory usage: 119.3+ MB

# %% [markdown]
# # 4. Model Training
# - 기본 모델들을 최종적으로 학습시킨다.
# - 여기서 완성된 모델이 추론을 수행하거나, 더 큰 모델로 합쳐짐.

# %%
from model import XGBoost

# %%
final_train_df = train_features_with_embeddings.merge(original_train_labels, on="building_id", how="left")
final_train_df = final_train_df.drop(columns='building_id')

# %%
xgb_ensemble = XGBoost(df=final_train_df, target_col="damage_grade")
xgb_ensemble.encoding(categorical_cols=original_categorical_cols)
xgb_ensemble.kfold(n_splits=5)

# %%
xgb_ensemble.train()
# Out:
# [0]	validation_0-mlogloss:0.97983
# [1]	validation_0-mlogloss:0.95607
# [2]	validation_0-mlogloss:0.93410
# [3]	validation_0-mlogloss:0.91376
# [4]	validation_0-mlogloss:0.89482
# [5]	validation_0-mlogloss:0.87724
# [6]	validation_0-mlogloss:0.86080
# [7]	validation_0-mlogloss:0.84523
# [8]	validation_0-mlogloss:0.83070
# [9]	validation_0-mlogloss:0.81708
# [10]	validation_0-mlogloss:0.80426
# [11]	validation_0-mlogloss:0.79228
# [12]	validation_0-mlogloss:0.78091
# [13]	validation_0-mlogloss:0.77029
# [14]	validation_0-mlogloss:0.76024
# [15]	validation_0-mlogloss:0.75082
# [16]	validation_0-mlogloss:0.74191
# [17]	validation_0-mlogloss:0.73346
# [18]	validation_0-mlogloss:0.72547
# [19]	validation_0-mlogloss:0.71800
# [20]	validation_0-mlogloss:0.71088
# [21]	validation_0-mlogloss:0.70416
# [22]	validation_0-mlogloss:0.69777
# [23]	validation_0-mlogloss:0.69175
# [24]	validation_0-mlogloss:0.68605
# [25]	validation_0-mlogloss:0.68063
# [26]	validation_0-mlogloss:0.67550
# [27]	validation_0-mlogloss:0.67061
# [28]	validation_0-mlogloss:0.66595
# [29]	validation_0-mlogloss:0.66155
# [30]	validation_0-mlogloss:0.65736
# [31]	validation_0-mlogloss:0.65334
# [32]	validation_0-mlogloss:0.64955
# [33]	validation_0-mlogloss:0.64591
# [34]	validation_0-mlogloss:0.64246
# [35]	validation_0-mlogloss:0.63911
# [36]	validation_0-mlogloss:0.63594
# [37]	validation_0-mlogloss:0.63292
# [38]	validation_0-mlogloss:0.63007
# [39]	validation_0-mlogloss:0.62728
# [40]	validation_0-mlogloss:0.62464
# [41]	validation_0-mlogloss:0.62206
# [42]	validation_0-mlogloss:0.61965
# [43]	validation_0-mlogloss:0.61727
# [44]	validation_0-mlogloss:0.61510
# [45]	validation_0-mlogloss:0.61293
# [46]	validation_0-mlogloss:0.61092
# [47]	validation_0-mlogloss:0.60894
# [48]	validation_0-mlogloss:0.60707
# [49]	validation_0-mlogloss:0.60527
# [50]	validation_0-mlogloss:0.60360
# [51]	validation_0-mlogloss:0.60197
# [52]	validation_0-mlogloss:0.60039
# [53]	validation_0-mlogloss:0.59887
# [54]	validation_0-mlogloss:0.59741
# [55]	validation_0-mlogloss:0.59601
# [56]	validation_0-mlogloss:0.59465
# [57]	validation_0-mlogloss:0.59340
# [58]	validation_0-mlogloss:0.59214
# [59]	validation_0-mlogloss:0.59094
# [60]	validation_0-mlogloss:0.58972
# [61]	validation_0-mlogloss:0.58859
# [62]	validation_0-mlogloss:0.58748
# [63]	validation_0-mlogloss:0.58639
# [64]	validation_0-mlogloss:0.58534
# [65]	validation_0-mlogloss:0.58429
# [66]	validation_0-mlogloss:0.58334
# [67]	validation_0-mlogloss:0.58240
# [68]	validation_0-mlogloss:0.58148
# [69]	validation_0-mlogloss:0.58060
# [70]	validation_0-mlogloss:0.57972
# [71]	validation_0-mlogloss:0.57893
# [72]	validation_0-mlogloss:0.57814
# [73]	validation_0-mlogloss:0.57737
# [74]	validation_0-mlogloss:0.57662
# [75]	validation_0-mlogloss:0.57591
# [76]	validation_0-mlogloss:0.57520
# [77]	validation_0-mlogloss:0.57452
# [78]	validation_0-mlogloss:0.57386
# [79]	validation_0-mlogloss:0.57323
# [80]	validation_0-mlogloss:0.57260
# [81]	validation_0-mlogloss:0.57200
# [82]	validation_0-mlogloss:0.57139
# [83]	validation_0-mlogloss:0.57081
# [84]	validation_0-mlogloss:0.57032
# [85]	validation_0-mlogloss:0.56978
# [86]	validation_0-mlogloss:0.56928
# [87]	validation_0-mlogloss:0.56876
# [88]	validation_0-mlogloss:0.56826
# [89]	validation_0-mlogloss:0.56779
# [90]	validation_0-mlogloss:0.56734
# [91]	validation_0-mlogloss:0.56688
# [92]	validation_0-mlogloss:0.56647
# [93]	validation_0-mlogloss:0.56607
# [94]	validation_0-mlogloss:0.56567
# [95]	validation_0-mlogloss:0.56527
# [96]	validation_0-mlogloss:0.56486
# [97]	validation_0-mlogloss:0.56451
# [98]	validation_0-mlogloss:0.56415
# [99]	validation_0-mlogloss:0.56379
# [100]	validation_0-mlogloss:0.56343
# [101]	validation_0-mlogloss:0.56307
# [102]	validation_0-mlogloss:0.56275
# [103]	validation_0-mlogloss:0.56240
# [104]	validation_0-mlogloss:0.56211
# [105]	validation_0-mlogloss:0.56180
# [106]	validation_0-mlogloss:0.56151
# [107]	validation_0-mlogloss:0.56123
# [108]	validation_0-mlogloss:0.56097
# [109]	validation_0-mlogloss:0.56069
# [110]	validation_0-mlogloss:0.56042
# [111]	validation_0-mlogloss:0.56017
# [112]	validation_0-mlogloss:0.55992
# [113]	validation_0-mlogloss:0.55969
# [114]	validation_0-mlogloss:0.55943
# [115]	validation_0-mlogloss:0.55922
# [116]	validation_0-mlogloss:0.55898
# [117]	validation_0-mlogloss:0.55873
# [118]	validation_0-mlogloss:0.55851
# [119]	validation_0-mlogloss:0.55831
# [120]	validation_0-mlogloss:0.55811
# [121]	validation_0-mlogloss:0.55791
# [122]	validation_0-mlogloss:0.55768
# [123]	validation_0-mlogloss:0.55747
# [124]	validation_0-mlogloss:0.55730
# [125]	validation_0-mlogloss:0.55709
# [126]	validation_0-mlogloss:0.55692
# [127]	validation_0-mlogloss:0.55672
# [128]	validation_0-mlogloss:0.55657
# [129]	validation_0-mlogloss:0.55639
# [130]	validation_0-mlogloss:0.55621
# [131]	validation_0-mlogloss:0.55605
# [132]	validation_0-mlogloss:0.55589
# [133]	validation_0-mlogloss:0.55573
# [134]	validation_0-mlogloss:0.55558
# [135]	validation_0-mlogloss:0.55543
# [136]	validation_0-mlogloss:0.55530
# [137]	validation_0-mlogloss:0.55515
# [138]	validation_0-mlogloss:0.55502
# [139]	validation_0-mlogloss:0.55490
# [140]	validation_0-mlogloss:0.55476
# [141]	validation_0-mlogloss:0.55464
# [142]	validation_0-mlogloss:0.55452
# [143]	validation_0-mlogloss:0.55438
# [144]	validation_0-mlogloss:0.55425
# [145]	validation_0-mlogloss:0.55413
# [146]	validation_0-mlogloss:0.55402
# [147]	validation_0-mlogloss:0.55389
# [148]	validation_0-mlogloss:0.55378
# [149]	validation_0-mlogloss:0.55366
# [150]	validation_0-mlogloss:0.55356
# [151]	validation_0-mlogloss:0.55345
# [152]	validation_0-mlogloss:0.55332
# [153]	validation_0-mlogloss:0.55323
# [154]	validation_0-mlogloss:0.55314
# [155]	validation_0-mlogloss:0.55301
# [156]	validation_0-mlogloss:0.55292
# [157]	validation_0-mlogloss:0.55281
# [158]	validation_0-mlogloss:0.55271
# [159]	validation_0-mlogloss:0.55259
# [160]	validation_0-mlogloss:0.55252
# [161]	validation_0-mlogloss:0.55243
# [162]	validation_0-mlogloss:0.55236
# [163]	validation_0-mlogloss:0.55226
# [164]	validation_0-mlogloss:0.55215
# [165]	validation_0-mlogloss:0.55207
# [166]	validation_0-mlogloss:0.55199
# [167]	validation_0-mlogloss:0.55191
# [168]	validation_0-mlogloss:0.55182
# [169]	validation_0-mlogloss:0.55170
# [170]	validation_0-mlogloss:0.55164
# [171]	validation_0-mlogloss:0.55153
# [172]	validation_0-mlogloss:0.55141
# [173]	validation_0-mlogloss:0.55134
# [174]	validation_0-mlogloss:0.55126
# [175]	validation_0-mlogloss:0.55118
# [176]	validation_0-mlogloss:0.55113
# [177]	validation_0-mlogloss:0.55104
# [178]	validation_0-mlogloss:0.55095
# [179]	validation_0-mlogloss:0.55087
# [180]	validation_0-mlogloss:0.55079
# [181]	validation_0-mlogloss:0.55072
# [182]	validation_0-mlogloss:0.55065
# [183]	validation_0-mlogloss:0.55056
# [184]	validation_0-mlogloss:0.55048
# [185]	validation_0-mlogloss:0.55041
# [186]	validation_0-mlogloss:0.55034
# [187]	validation_0-mlogloss:0.55026
# [188]	validation_0-mlogloss:0.55018
# [189]	validation_0-mlogloss:0.55011
# [190]	validation_0-mlogloss:0.55003
# [191]	validation_0-mlogloss:0.54996
# [192]	validation_0-mlogloss:0.54989
# [193]	validation_0-mlogloss:0.54979
# [194]	validation_0-mlogloss:0.54970
# [195]	validation_0-mlogloss:0.54963
# [196]	validation_0-mlogloss:0.54956
# [197]	validation_0-mlogloss:0.54949
# [198]	validation_0-mlogloss:0.54942
# [199]	validation_0-mlogloss:0.54935
# [200]	validation_0-mlogloss:0.54928
# [201]	validation_0-mlogloss:0.54919
# [202]	validation_0-mlogloss:0.54914
# [203]	validation_0-mlogloss:0.54908
# [204]	validation_0-mlogloss:0.54901
# [205]	validation_0-mlogloss:0.54893
# [206]	validation_0-mlogloss:0.54885
# [207]	validation_0-mlogloss:0.54880
# [208]	validation_0-mlogloss:0.54874
# [209]	validation_0-mlogloss:0.54866
# [210]	validation_0-mlogloss:0.54860
# [211]	validation_0-mlogloss:0.54852
# [212]	validation_0-mlogloss:0.54847
# [213]	validation_0-mlogloss:0.54840
# [214]	validation_0-mlogloss:0.54833
# [215]	validation_0-mlogloss:0.54826
# [216]	validation_0-mlogloss:0.54821
# [217]	validation_0-mlogloss:0.54817
# [218]	validation_0-mlogloss:0.54810
# [219]	validation_0-mlogloss:0.54806
# [220]	validation_0-mlogloss:0.54800
# [221]	validation_0-mlogloss:0.54796
# [222]	validation_0-mlogloss:0.54790
# [223]	validation_0-mlogloss:0.54785
# [224]	validation_0-mlogloss:0.54780
# [225]	validation_0-mlogloss:0.54775
# [226]	validation_0-mlogloss:0.54770
# [227]	validation_0-mlogloss:0.54765
# [228]	validation_0-mlogloss:0.54760
# [229]	validation_0-mlogloss:0.54754
# [230]	validation_0-mlogloss:0.54751
# [231]	validation_0-mlogloss:0.54746
# [232]	validation_0-mlogloss:0.54741
# [233]	validation_0-mlogloss:0.54736
# [234]	validation_0-mlogloss:0.54733
# [235]	validation_0-mlogloss:0.54729
# [236]	validation_0-mlogloss:0.54725
# [237]	validation_0-mlogloss:0.54722
# [238]	validation_0-mlogloss:0.54717
# [239]	validation_0-mlogloss:0.54714
# [240]	validation_0-mlogloss:0.54709
# [241]	validation_0-mlogloss:0.54703
# [242]	validation_0-mlogloss:0.54699
# [243]	validation_0-mlogloss:0.54696
# [244]	validation_0-mlogloss:0.54691
# [245]	validation_0-mlogloss:0.54688
# [246]	validation_0-mlogloss:0.54682
# [247]	validation_0-mlogloss:0.54679
# [248]	validation_0-mlogloss:0.54673
# [249]	validation_0-mlogloss:0.54670
# [250]	validation_0-mlogloss:0.54667
# [251]	validation_0-mlogloss:0.54663
# [252]	validation_0-mlogloss:0.54659
# [253]	validation_0-mlogloss:0.54655
# [254]	validation_0-mlogloss:0.54650
# [255]	validation_0-mlogloss:0.54646
# [256]	validation_0-mlogloss:0.54641
# [257]	validation_0-mlogloss:0.54636
# [258]	validation_0-mlogloss:0.54634
# [259]	validation_0-mlogloss:0.54629
# [260]	validation_0-mlogloss:0.54626
# [261]	validation_0-mlogloss:0.54622
# [262]	validation_0-mlogloss:0.54619
# [263]	validation_0-mlogloss:0.54615
# [264]	validation_0-mlogloss:0.54611
# [265]	validation_0-mlogloss:0.54605
# [266]	validation_0-mlogloss:0.54600
# [267]	validation_0-mlogloss:0.54597
# [268]	validation_0-mlogloss:0.54595
# [269]	validation_0-mlogloss:0.54590
# [270]	validation_0-mlogloss:0.54587
# [271]	validation_0-mlogloss:0.54583
# [272]	validation_0-mlogloss:0.54577
# [273]	validation_0-mlogloss:0.54574
# [274]	validation_0-mlogloss:0.54571
# [275]	validation_0-mlogloss:0.54569
# [276]	validation_0-mlogloss:0.54564
# [277]	validation_0-mlogloss:0.54559
# [278]	validation_0-mlogloss:0.54556
# [279]	validation_0-mlogloss:0.54552
# [280]	validation_0-mlogloss:0.54548
# [281]	validation_0-mlogloss:0.54544
# [282]	validation_0-mlogloss:0.54540
# [283]	validation_0-mlogloss:0.54537
# [284]	validation_0-mlogloss:0.54536
# [285]	validation_0-mlogloss:0.54533
# [286]	validation_0-mlogloss:0.54530
# [287]	validation_0-mlogloss:0.54527
# [288]	validation_0-mlogloss:0.54525
# [289]	validation_0-mlogloss:0.54522
# [290]	validation_0-mlogloss:0.54520
# [291]	validation_0-mlogloss:0.54515
# [292]	validation_0-mlogloss:0.54514
# [293]	validation_0-mlogloss:0.54511
# [294]	validation_0-mlogloss:0.54509
# [295]	validation_0-mlogloss:0.54506
# [296]	validation_0-mlogloss:0.54502
# [297]	validation_0-mlogloss:0.54499
# [298]	validation_0-mlogloss:0.54496
# [299]	validation_0-mlogloss:0.54494
# [300]	validation_0-mlogloss:0.54491
# [301]	validation_0-mlogloss:0.54488
# [302]	validation_0-mlogloss:0.54485
# [303]	validation_0-mlogloss:0.54481
# [304]	validation_0-mlogloss:0.54478
# [305]	validation_0-mlogloss:0.54476
# [306]	validation_0-mlogloss:0.54475
# [307]	validation_0-mlogloss:0.54471
# [308]	validation_0-mlogloss:0.54469
# [309]	validation_0-mlogloss:0.54467
# [310]	validation_0-mlogloss:0.54465
# [311]	validation_0-mlogloss:0.54462
# [312]	validation_0-mlogloss:0.54460
# [313]	validation_0-mlogloss:0.54458
# [314]	validation_0-mlogloss:0.54454
# [315]	validation_0-mlogloss:0.54451
# [316]	validation_0-mlogloss:0.54449
# [317]	validation_0-mlogloss:0.54448
# [318]	validation_0-mlogloss:0.54444
# [319]	validation_0-mlogloss:0.54441
# [320]	validation_0-mlogloss:0.54437
# [321]	validation_0-mlogloss:0.54436
# [322]	validation_0-mlogloss:0.54434
# [323]	validation_0-mlogloss:0.54430
# [324]	validation_0-mlogloss:0.54427
# [325]	validation_0-mlogloss:0.54423
# [326]	validation_0-mlogloss:0.54421
# [327]	validation_0-mlogloss:0.54419
# [328]	validation_0-mlogloss:0.54417
# [329]	validation_0-mlogloss:0.54413
# [330]	validation_0-mlogloss:0.54412
# [331]	validation_0-mlogloss:0.54408
# [332]	validation_0-mlogloss:0.54404
# [333]	validation_0-mlogloss:0.54403
# [334]	validation_0-mlogloss:0.54401
# [335]	validation_0-mlogloss:0.54399
# [336]	validation_0-mlogloss:0.54396
# [337]	validation_0-mlogloss:0.54392
# [338]	validation_0-mlogloss:0.54390
# [339]	validation_0-mlogloss:0.54388
# [340]	validation_0-mlogloss:0.54387
# [341]	validation_0-mlogloss:0.54385
# [342]	validation_0-mlogloss:0.54385
# [343]	validation_0-mlogloss:0.54381
# [344]	validation_0-mlogloss:0.54380
# [345]	validation_0-mlogloss:0.54378
# [346]	validation_0-mlogloss:0.54377
# [347]	validation_0-mlogloss:0.54376
# [348]	validation_0-mlogloss:0.54373
# [349]	validation_0-mlogloss:0.54372
# [350]	validation_0-mlogloss:0.54369
# [351]	validation_0-mlogloss:0.54365
# [352]	validation_0-mlogloss:0.54363
# [353]	validation_0-mlogloss:0.54361
# [354]	validation_0-mlogloss:0.54358
# [355]	validation_0-mlogloss:0.54357
# [356]	validation_0-mlogloss:0.54356
# [357]	validation_0-mlogloss:0.54355
# [358]	validation_0-mlogloss:0.54353
# [359]	validation_0-mlogloss:0.54350
# [360]	validation_0-mlogloss:0.54348
# [361]	validation_0-mlogloss:0.54348
# [362]	validation_0-mlogloss:0.54346
# [363]	validation_0-mlogloss:0.54343
# [364]	validation_0-mlogloss:0.54341
# [365]	validation_0-mlogloss:0.54339
# [366]	validation_0-mlogloss:0.54337
# [367]	validation_0-mlogloss:0.54335
# [368]	validation_0-mlogloss:0.54333
# [369]	validation_0-mlogloss:0.54333
# [370]	validation_0-mlogloss:0.54330
# [371]	validation_0-mlogloss:0.54329
# [372]	validation_0-mlogloss:0.54326
# [373]	validation_0-mlogloss:0.54324
# [374]	validation_0-mlogloss:0.54321
# [375]	validation_0-mlogloss:0.54319
# [376]	validation_0-mlogloss:0.54317
# [377]	validation_0-mlogloss:0.54315
# [378]	validation_0-mlogloss:0.54314
# [379]	validation_0-mlogloss:0.54314
# [380]	validation_0-mlogloss:0.54312
# [381]	validation_0-mlogloss:0.54311
# [382]	validation_0-mlogloss:0.54307
# [383]	validation_0-mlogloss:0.54305
# [384]	validation_0-mlogloss:0.54304
# [385]	validation_0-mlogloss:0.54303
# [386]	validation_0-mlogloss:0.54301
# [387]	validation_0-mlogloss:0.54299
# [388]	validation_0-mlogloss:0.54297
# [389]	validation_0-mlogloss:0.54296
# [390]	validation_0-mlogloss:0.54294
# [391]	validation_0-mlogloss:0.54291
# [392]	validation_0-mlogloss:0.54289
# [393]	validation_0-mlogloss:0.54286
# [394]	validation_0-mlogloss:0.54285
# [395]	validation_0-mlogloss:0.54283
# [396]	validation_0-mlogloss:0.54281
# [397]	validation_0-mlogloss:0.54281
# [398]	validation_0-mlogloss:0.54279
# [399]	validation_0-mlogloss:0.54279
# [400]	validation_0-mlogloss:0.54278
# [401]	validation_0-mlogloss:0.54276
# [402]	validation_0-mlogloss:0.54276
# [403]	validation_0-mlogloss:0.54275
# [404]	validation_0-mlogloss:0.54274
# [405]	validation_0-mlogloss:0.54272
# [406]	validation_0-mlogloss:0.54269
# [407]	validation_0-mlogloss:0.54266
# [408]	validation_0-mlogloss:0.54265
# [409]	validation_0-mlogloss:0.54263
# [410]	validation_0-mlogloss:0.54263
# [411]	validation_0-mlogloss:0.54261
# [412]	validation_0-mlogloss:0.54260
# [413]	validation_0-mlogloss:0.54259
# [414]	validation_0-mlogloss:0.54258
# [415]	validation_0-mlogloss:0.54257
# [416]	validation_0-mlogloss:0.54257
# [417]	validation_0-mlogloss:0.54256
# [418]	validation_0-mlogloss:0.54255
# [419]	validation_0-mlogloss:0.54253
# [420]	validation_0-mlogloss:0.54252
# [421]	validation_0-mlogloss:0.54251
# [422]	validation_0-mlogloss:0.54249
# [423]	validation_0-mlogloss:0.54248
# [424]	validation_0-mlogloss:0.54248
# [425]	validation_0-mlogloss:0.54246
# [426]	validation_0-mlogloss:0.54245
# [427]	validation_0-mlogloss:0.54244
# [428]	validation_0-mlogloss:0.54243
# [429]	validation_0-mlogloss:0.54241
# [430]	validation_0-mlogloss:0.54239
# [431]	validation_0-mlogloss:0.54237
# [432]	validation_0-mlogloss:0.54235
# [433]	validation_0-mlogloss:0.54233
# [434]	validation_0-mlogloss:0.54232
# [435]	validation_0-mlogloss:0.54229
# [436]	validation_0-mlogloss:0.54229
# [437]	validation_0-mlogloss:0.54227
# [438]	validation_0-mlogloss:0.54225
# [439]	validation_0-mlogloss:0.54224
# [440]	validation_0-mlogloss:0.54223
# [441]	validation_0-mlogloss:0.54222
# [442]	validation_0-mlogloss:0.54220
# [443]	validation_0-mlogloss:0.54219
# [444]	validation_0-mlogloss:0.54217
# [445]	validation_0-mlogloss:0.54215
# [446]	validation_0-mlogloss:0.54214
# [447]	validation_0-mlogloss:0.54212
# [448]	validation_0-mlogloss:0.54211
# [449]	validation_0-mlogloss:0.54211
# [450]	validation_0-mlogloss:0.54209
# [451]	validation_0-mlogloss:0.54209
# [452]	validation_0-mlogloss:0.54209
# [453]	validation_0-mlogloss:0.54207
# [454]	validation_0-mlogloss:0.54206
# [455]	validation_0-mlogloss:0.54206
# [456]	validation_0-mlogloss:0.54204
# [457]	validation_0-mlogloss:0.54204
# [458]	validation_0-mlogloss:0.54201
# [459]	validation_0-mlogloss:0.54200
# [460]	validation_0-mlogloss:0.54199
# [461]	validation_0-mlogloss:0.54198
# [462]	validation_0-mlogloss:0.54197
# [463]	validation_0-mlogloss:0.54196
# [464]	validation_0-mlogloss:0.54195
# [465]	validation_0-mlogloss:0.54193
# [466]	validation_0-mlogloss:0.54191
# [467]	validation_0-mlogloss:0.54190
# [468]	validation_0-mlogloss:0.54190
# [469]	validation_0-mlogloss:0.54187
# [470]	validation_0-mlogloss:0.54186
# [471]	validation_0-mlogloss:0.54185
# [472]	validation_0-mlogloss:0.54184
# [473]	validation_0-mlogloss:0.54183
# [474]	validation_0-mlogloss:0.54182
# [475]	validation_0-mlogloss:0.54181
# [476]	validation_0-mlogloss:0.54179
# [477]	validation_0-mlogloss:0.54177
# [478]	validation_0-mlogloss:0.54176
# [479]	validation_0-mlogloss:0.54175
# [480]	validation_0-mlogloss:0.54173
# [481]	validation_0-mlogloss:0.54173
# [482]	validation_0-mlogloss:0.54170
# [483]	validation_0-mlogloss:0.54169
# [484]	validation_0-mlogloss:0.54168
# [485]	validation_0-mlogloss:0.54168
# [486]	validation_0-mlogloss:0.54166
# [487]	validation_0-mlogloss:0.54166
# [488]	validation_0-mlogloss:0.54166
# [489]	validation_0-mlogloss:0.54166
# [490]	validation_0-mlogloss:0.54164
# [491]	validation_0-mlogloss:0.54163
# [492]	validation_0-mlogloss:0.54161
# [493]	validation_0-mlogloss:0.54160
# [494]	validation_0-mlogloss:0.54159
# [495]	validation_0-mlogloss:0.54157
# [496]	validation_0-mlogloss:0.54158
# [497]	validation_0-mlogloss:0.54158
# [498]	validation_0-mlogloss:0.54157
# [499]	validation_0-mlogloss:0.54157
# [Fold 1/5] Best Score: 0.5416
# [0]	validation_0-mlogloss:0.98000
# [1]	validation_0-mlogloss:0.95643
# [2]	validation_0-mlogloss:0.93456
# [3]	validation_0-mlogloss:0.91430
# [4]	validation_0-mlogloss:0.89541
# [5]	validation_0-mlogloss:0.87782
# [6]	validation_0-mlogloss:0.86137
# [7]	validation_0-mlogloss:0.84588
# [8]	validation_0-mlogloss:0.83137
# [9]	validation_0-mlogloss:0.81775
# [10]	validation_0-mlogloss:0.80502
# [11]	validation_0-mlogloss:0.79300
# [12]	validation_0-mlogloss:0.78176
# [13]	validation_0-mlogloss:0.77112
# [14]	validation_0-mlogloss:0.76100
# [15]	validation_0-mlogloss:0.75152
# [16]	validation_0-mlogloss:0.74254
# [17]	validation_0-mlogloss:0.73407
# [18]	validation_0-mlogloss:0.72604
# [19]	validation_0-mlogloss:0.71845
# [20]	validation_0-mlogloss:0.71127
# [21]	validation_0-mlogloss:0.70449
# [22]	validation_0-mlogloss:0.69804
# [23]	validation_0-mlogloss:0.69196
# [24]	validation_0-mlogloss:0.68619
# [25]	validation_0-mlogloss:0.68074
# [26]	validation_0-mlogloss:0.67559
# [27]	validation_0-mlogloss:0.67065
# [28]	validation_0-mlogloss:0.66600
# [29]	validation_0-mlogloss:0.66155
# [30]	validation_0-mlogloss:0.65731
# [31]	validation_0-mlogloss:0.65331
# [32]	validation_0-mlogloss:0.64947
# [33]	validation_0-mlogloss:0.64582
# [34]	validation_0-mlogloss:0.64226
# [35]	validation_0-mlogloss:0.63889
# [36]	validation_0-mlogloss:0.63566
# [37]	validation_0-mlogloss:0.63254
# [38]	validation_0-mlogloss:0.62962
# [39]	validation_0-mlogloss:0.62677
# [40]	validation_0-mlogloss:0.62413
# [41]	validation_0-mlogloss:0.62153
# [42]	validation_0-mlogloss:0.61903
# [43]	validation_0-mlogloss:0.61664
# [44]	validation_0-mlogloss:0.61445
# [45]	validation_0-mlogloss:0.61233
# [46]	validation_0-mlogloss:0.61028
# [47]	validation_0-mlogloss:0.60834
# [48]	validation_0-mlogloss:0.60644
# [49]	validation_0-mlogloss:0.60459
# [50]	validation_0-mlogloss:0.60286
# [51]	validation_0-mlogloss:0.60119
# [52]	validation_0-mlogloss:0.59958
# [53]	validation_0-mlogloss:0.59800
# [54]	validation_0-mlogloss:0.59648
# [55]	validation_0-mlogloss:0.59499
# [56]	validation_0-mlogloss:0.59357
# [57]	validation_0-mlogloss:0.59223
# [58]	validation_0-mlogloss:0.59094
# [59]	validation_0-mlogloss:0.58967
# [60]	validation_0-mlogloss:0.58846
# [61]	validation_0-mlogloss:0.58727
# [62]	validation_0-mlogloss:0.58610
# [63]	validation_0-mlogloss:0.58497
# [64]	validation_0-mlogloss:0.58389
# [65]	validation_0-mlogloss:0.58284
# [66]	validation_0-mlogloss:0.58185
# [67]	validation_0-mlogloss:0.58091
# [68]	validation_0-mlogloss:0.57998
# [69]	validation_0-mlogloss:0.57909
# [70]	validation_0-mlogloss:0.57823
# [71]	validation_0-mlogloss:0.57741
# [72]	validation_0-mlogloss:0.57661
# [73]	validation_0-mlogloss:0.57581
# [74]	validation_0-mlogloss:0.57505
# [75]	validation_0-mlogloss:0.57433
# [76]	validation_0-mlogloss:0.57363
# [77]	validation_0-mlogloss:0.57294
# [78]	validation_0-mlogloss:0.57227
# [79]	validation_0-mlogloss:0.57165
# [80]	validation_0-mlogloss:0.57105
# [81]	validation_0-mlogloss:0.57043
# [82]	validation_0-mlogloss:0.56983
# [83]	validation_0-mlogloss:0.56927
# [84]	validation_0-mlogloss:0.56871
# [85]	validation_0-mlogloss:0.56815
# [86]	validation_0-mlogloss:0.56765
# [87]	validation_0-mlogloss:0.56714
# [88]	validation_0-mlogloss:0.56665
# [89]	validation_0-mlogloss:0.56616
# [90]	validation_0-mlogloss:0.56570
# [91]	validation_0-mlogloss:0.56523
# [92]	validation_0-mlogloss:0.56476
# [93]	validation_0-mlogloss:0.56432
# [94]	validation_0-mlogloss:0.56391
# [95]	validation_0-mlogloss:0.56351
# [96]	validation_0-mlogloss:0.56309
# [97]	validation_0-mlogloss:0.56269
# [98]	validation_0-mlogloss:0.56232
# [99]	validation_0-mlogloss:0.56196
# [100]	validation_0-mlogloss:0.56158
# [101]	validation_0-mlogloss:0.56125
# [102]	validation_0-mlogloss:0.56092
# [103]	validation_0-mlogloss:0.56060
# [104]	validation_0-mlogloss:0.56028
# [105]	validation_0-mlogloss:0.55995
# [106]	validation_0-mlogloss:0.55965
# [107]	validation_0-mlogloss:0.55933
# [108]	validation_0-mlogloss:0.55908
# [109]	validation_0-mlogloss:0.55879
# [110]	validation_0-mlogloss:0.55849
# [111]	validation_0-mlogloss:0.55822
# [112]	validation_0-mlogloss:0.55795
# [113]	validation_0-mlogloss:0.55770
# [114]	validation_0-mlogloss:0.55745
# [115]	validation_0-mlogloss:0.55723
# [116]	validation_0-mlogloss:0.55698
# [117]	validation_0-mlogloss:0.55674
# [118]	validation_0-mlogloss:0.55651
# [119]	validation_0-mlogloss:0.55629
# [120]	validation_0-mlogloss:0.55608
# [121]	validation_0-mlogloss:0.55586
# [122]	validation_0-mlogloss:0.55565
# [123]	validation_0-mlogloss:0.55546
# [124]	validation_0-mlogloss:0.55525
# [125]	validation_0-mlogloss:0.55508
# [126]	validation_0-mlogloss:0.55488
# [127]	validation_0-mlogloss:0.55470
# [128]	validation_0-mlogloss:0.55452
# [129]	validation_0-mlogloss:0.55435
# [130]	validation_0-mlogloss:0.55419
# [131]	validation_0-mlogloss:0.55401
# [132]	validation_0-mlogloss:0.55384
# [133]	validation_0-mlogloss:0.55369
# [134]	validation_0-mlogloss:0.55351
# [135]	validation_0-mlogloss:0.55337
# [136]	validation_0-mlogloss:0.55322
# [137]	validation_0-mlogloss:0.55306
# [138]	validation_0-mlogloss:0.55291
# [139]	validation_0-mlogloss:0.55275
# [140]	validation_0-mlogloss:0.55262
# [141]	validation_0-mlogloss:0.55250
# [142]	validation_0-mlogloss:0.55235
# [143]	validation_0-mlogloss:0.55223
# [144]	validation_0-mlogloss:0.55211
# [145]	validation_0-mlogloss:0.55200
# [146]	validation_0-mlogloss:0.55186
# [147]	validation_0-mlogloss:0.55171
# [148]	validation_0-mlogloss:0.55159
# [149]	validation_0-mlogloss:0.55150
# [150]	validation_0-mlogloss:0.55137
# [151]	validation_0-mlogloss:0.55124
# [152]	validation_0-mlogloss:0.55113
# [153]	validation_0-mlogloss:0.55102
# [154]	validation_0-mlogloss:0.55089
# [155]	validation_0-mlogloss:0.55079
# [156]	validation_0-mlogloss:0.55070
# [157]	validation_0-mlogloss:0.55058
# [158]	validation_0-mlogloss:0.55050
# [159]	validation_0-mlogloss:0.55040
# [160]	validation_0-mlogloss:0.55031
# [161]	validation_0-mlogloss:0.55021
# [162]	validation_0-mlogloss:0.55012
# [163]	validation_0-mlogloss:0.55002
# [164]	validation_0-mlogloss:0.54991
# [165]	validation_0-mlogloss:0.54982
# [166]	validation_0-mlogloss:0.54972
# [167]	validation_0-mlogloss:0.54962
# [168]	validation_0-mlogloss:0.54954
# [169]	validation_0-mlogloss:0.54945
# [170]	validation_0-mlogloss:0.54938
# [171]	validation_0-mlogloss:0.54929
# [172]	validation_0-mlogloss:0.54920
# [173]	validation_0-mlogloss:0.54912
# [174]	validation_0-mlogloss:0.54904
# [175]	validation_0-mlogloss:0.54894
# [176]	validation_0-mlogloss:0.54887
# [177]	validation_0-mlogloss:0.54878
# [178]	validation_0-mlogloss:0.54869
# [179]	validation_0-mlogloss:0.54862
# [180]	validation_0-mlogloss:0.54854
# [181]	validation_0-mlogloss:0.54847
# [182]	validation_0-mlogloss:0.54839
# [183]	validation_0-mlogloss:0.54832
# [184]	validation_0-mlogloss:0.54823
# [185]	validation_0-mlogloss:0.54818
# [186]	validation_0-mlogloss:0.54811
# [187]	validation_0-mlogloss:0.54802
# [188]	validation_0-mlogloss:0.54796
# [189]	validation_0-mlogloss:0.54789
# [190]	validation_0-mlogloss:0.54783
# [191]	validation_0-mlogloss:0.54774
# [192]	validation_0-mlogloss:0.54765
# [193]	validation_0-mlogloss:0.54757
# [194]	validation_0-mlogloss:0.54751
# [195]	validation_0-mlogloss:0.54746
# [196]	validation_0-mlogloss:0.54737
# [197]	validation_0-mlogloss:0.54729
# [198]	validation_0-mlogloss:0.54723
# [199]	validation_0-mlogloss:0.54717
# [200]	validation_0-mlogloss:0.54711
# [201]	validation_0-mlogloss:0.54704
# [202]	validation_0-mlogloss:0.54699
# [203]	validation_0-mlogloss:0.54693
# [204]	validation_0-mlogloss:0.54685
# [205]	validation_0-mlogloss:0.54677
# [206]	validation_0-mlogloss:0.54671
# [207]	validation_0-mlogloss:0.54666
# [208]	validation_0-mlogloss:0.54660
# [209]	validation_0-mlogloss:0.54653
# [210]	validation_0-mlogloss:0.54647
# [211]	validation_0-mlogloss:0.54639
# [212]	validation_0-mlogloss:0.54633
# [213]	validation_0-mlogloss:0.54628
# [214]	validation_0-mlogloss:0.54623
# [215]	validation_0-mlogloss:0.54615
# [216]	validation_0-mlogloss:0.54608
# [217]	validation_0-mlogloss:0.54603
# [218]	validation_0-mlogloss:0.54597
# [219]	validation_0-mlogloss:0.54591
# [220]	validation_0-mlogloss:0.54586
# [221]	validation_0-mlogloss:0.54582
# [222]	validation_0-mlogloss:0.54577
# [223]	validation_0-mlogloss:0.54571
# [224]	validation_0-mlogloss:0.54567
# [225]	validation_0-mlogloss:0.54562
# [226]	validation_0-mlogloss:0.54554
# [227]	validation_0-mlogloss:0.54550
# [228]	validation_0-mlogloss:0.54545
# [229]	validation_0-mlogloss:0.54539
# [230]	validation_0-mlogloss:0.54534
# [231]	validation_0-mlogloss:0.54528
# [232]	validation_0-mlogloss:0.54522
# [233]	validation_0-mlogloss:0.54518
# [234]	validation_0-mlogloss:0.54513
# [235]	validation_0-mlogloss:0.54507
# [236]	validation_0-mlogloss:0.54503
# [237]	validation_0-mlogloss:0.54496
# [238]	validation_0-mlogloss:0.54492
# [239]	validation_0-mlogloss:0.54486
# [240]	validation_0-mlogloss:0.54482
# [241]	validation_0-mlogloss:0.54476
# [242]	validation_0-mlogloss:0.54471
# [243]	validation_0-mlogloss:0.54469
# [244]	validation_0-mlogloss:0.54463
# [245]	validation_0-mlogloss:0.54459
# [246]	validation_0-mlogloss:0.54454
# [247]	validation_0-mlogloss:0.54451
# [248]	validation_0-mlogloss:0.54447
# [249]	validation_0-mlogloss:0.54444
# [250]	validation_0-mlogloss:0.54439
# [251]	validation_0-mlogloss:0.54437
# [252]	validation_0-mlogloss:0.54435
# [253]	validation_0-mlogloss:0.54432
# [254]	validation_0-mlogloss:0.54427
# [255]	validation_0-mlogloss:0.54423
# [256]	validation_0-mlogloss:0.54417
# [257]	validation_0-mlogloss:0.54413
# [258]	validation_0-mlogloss:0.54409
# [259]	validation_0-mlogloss:0.54405
# [260]	validation_0-mlogloss:0.54401
# [261]	validation_0-mlogloss:0.54398
# [262]	validation_0-mlogloss:0.54393
# [263]	validation_0-mlogloss:0.54389
# [264]	validation_0-mlogloss:0.54386
# [265]	validation_0-mlogloss:0.54384
# [266]	validation_0-mlogloss:0.54382
# [267]	validation_0-mlogloss:0.54378
# [268]	validation_0-mlogloss:0.54374
# [269]	validation_0-mlogloss:0.54370
# [270]	validation_0-mlogloss:0.54367
# [271]	validation_0-mlogloss:0.54364
# [272]	validation_0-mlogloss:0.54361
# [273]	validation_0-mlogloss:0.54357
# [274]	validation_0-mlogloss:0.54353
# [275]	validation_0-mlogloss:0.54350
# [276]	validation_0-mlogloss:0.54347
# [277]	validation_0-mlogloss:0.54343
# [278]	validation_0-mlogloss:0.54340
# [279]	validation_0-mlogloss:0.54337
# [280]	validation_0-mlogloss:0.54334
# [281]	validation_0-mlogloss:0.54331
# [282]	validation_0-mlogloss:0.54328
# [283]	validation_0-mlogloss:0.54325
# [284]	validation_0-mlogloss:0.54321
# [285]	validation_0-mlogloss:0.54318
# [286]	validation_0-mlogloss:0.54315
# [287]	validation_0-mlogloss:0.54312
# [288]	validation_0-mlogloss:0.54309
# [289]	validation_0-mlogloss:0.54308
# [290]	validation_0-mlogloss:0.54305
# [291]	validation_0-mlogloss:0.54303
# [292]	validation_0-mlogloss:0.54301
# [293]	validation_0-mlogloss:0.54297
# [294]	validation_0-mlogloss:0.54296
# [295]	validation_0-mlogloss:0.54293
# [296]	validation_0-mlogloss:0.54291
# [297]	validation_0-mlogloss:0.54289
# [298]	validation_0-mlogloss:0.54286
# [299]	validation_0-mlogloss:0.54283
# [300]	validation_0-mlogloss:0.54281
# [301]	validation_0-mlogloss:0.54278
# [302]	validation_0-mlogloss:0.54276
# [303]	validation_0-mlogloss:0.54273
# [304]	validation_0-mlogloss:0.54271
# [305]	validation_0-mlogloss:0.54269
# [306]	validation_0-mlogloss:0.54269
# [307]	validation_0-mlogloss:0.54266
# [308]	validation_0-mlogloss:0.54264
# [309]	validation_0-mlogloss:0.54261
# [310]	validation_0-mlogloss:0.54259
# [311]	validation_0-mlogloss:0.54257
# [312]	validation_0-mlogloss:0.54256
# [313]	validation_0-mlogloss:0.54254
# [314]	validation_0-mlogloss:0.54251
# [315]	validation_0-mlogloss:0.54250
# [316]	validation_0-mlogloss:0.54247
# [317]	validation_0-mlogloss:0.54246
# [318]	validation_0-mlogloss:0.54245
# [319]	validation_0-mlogloss:0.54243
# [320]	validation_0-mlogloss:0.54239
# [321]	validation_0-mlogloss:0.54237
# [322]	validation_0-mlogloss:0.54233
# [323]	validation_0-mlogloss:0.54229
# [324]	validation_0-mlogloss:0.54227
# [325]	validation_0-mlogloss:0.54226
# [326]	validation_0-mlogloss:0.54225
# [327]	validation_0-mlogloss:0.54221
# [328]	validation_0-mlogloss:0.54219
# [329]	validation_0-mlogloss:0.54220
# [330]	validation_0-mlogloss:0.54217
# [331]	validation_0-mlogloss:0.54215
# [332]	validation_0-mlogloss:0.54212
# [333]	validation_0-mlogloss:0.54210
# [334]	validation_0-mlogloss:0.54208
# [335]	validation_0-mlogloss:0.54206
# [336]	validation_0-mlogloss:0.54205
# [337]	validation_0-mlogloss:0.54202
# [338]	validation_0-mlogloss:0.54201
# [339]	validation_0-mlogloss:0.54199
# [340]	validation_0-mlogloss:0.54197
# [341]	validation_0-mlogloss:0.54195
# [342]	validation_0-mlogloss:0.54194
# [343]	validation_0-mlogloss:0.54194
# [344]	validation_0-mlogloss:0.54192
# [345]	validation_0-mlogloss:0.54190
# [346]	validation_0-mlogloss:0.54189
# [347]	validation_0-mlogloss:0.54188
# [348]	validation_0-mlogloss:0.54186
# [349]	validation_0-mlogloss:0.54186
# [350]	validation_0-mlogloss:0.54185
# [351]	validation_0-mlogloss:0.54183
# [352]	validation_0-mlogloss:0.54182
# [353]	validation_0-mlogloss:0.54180
# [354]	validation_0-mlogloss:0.54179
# [355]	validation_0-mlogloss:0.54177
# [356]	validation_0-mlogloss:0.54176
# [357]	validation_0-mlogloss:0.54174
# [358]	validation_0-mlogloss:0.54172
# [359]	validation_0-mlogloss:0.54170
# [360]	validation_0-mlogloss:0.54169
# [361]	validation_0-mlogloss:0.54167
# [362]	validation_0-mlogloss:0.54166
# [363]	validation_0-mlogloss:0.54164
# [364]	validation_0-mlogloss:0.54163
# [365]	validation_0-mlogloss:0.54161
# [366]	validation_0-mlogloss:0.54159
# [367]	validation_0-mlogloss:0.54157
# [368]	validation_0-mlogloss:0.54154
# [369]	validation_0-mlogloss:0.54154
# [370]	validation_0-mlogloss:0.54153
# [371]	validation_0-mlogloss:0.54151
# [372]	validation_0-mlogloss:0.54150
# [373]	validation_0-mlogloss:0.54149
# [374]	validation_0-mlogloss:0.54147
# [375]	validation_0-mlogloss:0.54146
# [376]	validation_0-mlogloss:0.54144
# [377]	validation_0-mlogloss:0.54143
# [378]	validation_0-mlogloss:0.54140
# [379]	validation_0-mlogloss:0.54139
# [380]	validation_0-mlogloss:0.54138
# [381]	validation_0-mlogloss:0.54137
# [382]	validation_0-mlogloss:0.54135
# [383]	validation_0-mlogloss:0.54134
# [384]	validation_0-mlogloss:0.54133
# [385]	validation_0-mlogloss:0.54133
# [386]	validation_0-mlogloss:0.54131
# [387]	validation_0-mlogloss:0.54130
# [388]	validation_0-mlogloss:0.54126
# [389]	validation_0-mlogloss:0.54124
# [390]	validation_0-mlogloss:0.54121
# [391]	validation_0-mlogloss:0.54121
# [392]	validation_0-mlogloss:0.54119
# [393]	validation_0-mlogloss:0.54118
# [394]	validation_0-mlogloss:0.54114
# [395]	validation_0-mlogloss:0.54115
# [396]	validation_0-mlogloss:0.54113
# [397]	validation_0-mlogloss:0.54112
# [398]	validation_0-mlogloss:0.54110
# [399]	validation_0-mlogloss:0.54108
# [400]	validation_0-mlogloss:0.54107
# [401]	validation_0-mlogloss:0.54106
# [402]	validation_0-mlogloss:0.54105
# [403]	validation_0-mlogloss:0.54103
# [404]	validation_0-mlogloss:0.54102
# [405]	validation_0-mlogloss:0.54100
# [406]	validation_0-mlogloss:0.54100
# [407]	validation_0-mlogloss:0.54099
# [408]	validation_0-mlogloss:0.54097
# [409]	validation_0-mlogloss:0.54097
# [410]	validation_0-mlogloss:0.54095
# [411]	validation_0-mlogloss:0.54093
# [412]	validation_0-mlogloss:0.54092
# [413]	validation_0-mlogloss:0.54089
# [414]	validation_0-mlogloss:0.54087
# [415]	validation_0-mlogloss:0.54086
# [416]	validation_0-mlogloss:0.54085
# [417]	validation_0-mlogloss:0.54085
# [418]	validation_0-mlogloss:0.54084
# [419]	validation_0-mlogloss:0.54084
# [420]	validation_0-mlogloss:0.54082
# [421]	validation_0-mlogloss:0.54081
# [422]	validation_0-mlogloss:0.54080
# [423]	validation_0-mlogloss:0.54079
# [424]	validation_0-mlogloss:0.54078
# [425]	validation_0-mlogloss:0.54076
# [426]	validation_0-mlogloss:0.54075
# [427]	validation_0-mlogloss:0.54073
# [428]	validation_0-mlogloss:0.54073
# [429]	validation_0-mlogloss:0.54072
# [430]	validation_0-mlogloss:0.54070
# [431]	validation_0-mlogloss:0.54068
# [432]	validation_0-mlogloss:0.54068
# [433]	validation_0-mlogloss:0.54065
# [434]	validation_0-mlogloss:0.54064
# [435]	validation_0-mlogloss:0.54063
# [436]	validation_0-mlogloss:0.54062
# [437]	validation_0-mlogloss:0.54061
# [438]	validation_0-mlogloss:0.54061
# [439]	validation_0-mlogloss:0.54059
# [440]	validation_0-mlogloss:0.54058
# [441]	validation_0-mlogloss:0.54056
# [442]	validation_0-mlogloss:0.54054
# [443]	validation_0-mlogloss:0.54052
# [444]	validation_0-mlogloss:0.54052
# [445]	validation_0-mlogloss:0.54052
# [446]	validation_0-mlogloss:0.54052
# [447]	validation_0-mlogloss:0.54051
# [448]	validation_0-mlogloss:0.54048
# [449]	validation_0-mlogloss:0.54048
# [450]	validation_0-mlogloss:0.54047
# [451]	validation_0-mlogloss:0.54045
# [452]	validation_0-mlogloss:0.54044
# [453]	validation_0-mlogloss:0.54044
# [454]	validation_0-mlogloss:0.54042
# [455]	validation_0-mlogloss:0.54040
# [456]	validation_0-mlogloss:0.54041
# [457]	validation_0-mlogloss:0.54041
# [458]	validation_0-mlogloss:0.54039
# [459]	validation_0-mlogloss:0.54037
# [460]	validation_0-mlogloss:0.54037
# [461]	validation_0-mlogloss:0.54036
# [462]	validation_0-mlogloss:0.54036
# [463]	validation_0-mlogloss:0.54035
# [464]	validation_0-mlogloss:0.54035
# [465]	validation_0-mlogloss:0.54034
# [466]	validation_0-mlogloss:0.54033
# [467]	validation_0-mlogloss:0.54032
# [468]	validation_0-mlogloss:0.54031
# [469]	validation_0-mlogloss:0.54029
# [470]	validation_0-mlogloss:0.54029
# [471]	validation_0-mlogloss:0.54027
# [472]	validation_0-mlogloss:0.54027
# [473]	validation_0-mlogloss:0.54026
# [474]	validation_0-mlogloss:0.54025
# [475]	validation_0-mlogloss:0.54024
# [476]	validation_0-mlogloss:0.54024
# [477]	validation_0-mlogloss:0.54025
# [478]	validation_0-mlogloss:0.54024
# [479]	validation_0-mlogloss:0.54024
# [480]	validation_0-mlogloss:0.54023
# [481]	validation_0-mlogloss:0.54022
# [482]	validation_0-mlogloss:0.54021
# [483]	validation_0-mlogloss:0.54020
# [484]	validation_0-mlogloss:0.54020
# [485]	validation_0-mlogloss:0.54019
# [486]	validation_0-mlogloss:0.54018
# [487]	validation_0-mlogloss:0.54017
# [488]	validation_0-mlogloss:0.54017
# [489]	validation_0-mlogloss:0.54016
# [490]	validation_0-mlogloss:0.54016
# [491]	validation_0-mlogloss:0.54015
# [492]	validation_0-mlogloss:0.54014
# [493]	validation_0-mlogloss:0.54015
# [494]	validation_0-mlogloss:0.54014
# [495]	validation_0-mlogloss:0.54013
# [496]	validation_0-mlogloss:0.54012
# [497]	validation_0-mlogloss:0.54011
# [498]	validation_0-mlogloss:0.54011
# [499]	validation_0-mlogloss:0.54009
# [Fold 2/5] Best Score: 0.5401
# [0]	validation_0-mlogloss:0.97988
# [1]	validation_0-mlogloss:0.95619
# [2]	validation_0-mlogloss:0.93413
# [3]	validation_0-mlogloss:0.91365
# [4]	validation_0-mlogloss:0.89463
# [5]	validation_0-mlogloss:0.87683
# [6]	validation_0-mlogloss:0.86020
# [7]	validation_0-mlogloss:0.84464
# [8]	validation_0-mlogloss:0.82997
# [9]	validation_0-mlogloss:0.81620
# [10]	validation_0-mlogloss:0.80330
# [11]	validation_0-mlogloss:0.79116
# [12]	validation_0-mlogloss:0.77966
# [13]	validation_0-mlogloss:0.76893
# [14]	validation_0-mlogloss:0.75878
# [15]	validation_0-mlogloss:0.74923
# [16]	validation_0-mlogloss:0.74021
# [17]	validation_0-mlogloss:0.73166
# [18]	validation_0-mlogloss:0.72355
# [19]	validation_0-mlogloss:0.71591
# [20]	validation_0-mlogloss:0.70863
# [21]	validation_0-mlogloss:0.70174
# [22]	validation_0-mlogloss:0.69535
# [23]	validation_0-mlogloss:0.68922
# [24]	validation_0-mlogloss:0.68339
# [25]	validation_0-mlogloss:0.67790
# [26]	validation_0-mlogloss:0.67260
# [27]	validation_0-mlogloss:0.66763
# [28]	validation_0-mlogloss:0.66285
# [29]	validation_0-mlogloss:0.65835
# [30]	validation_0-mlogloss:0.65406
# [31]	validation_0-mlogloss:0.65002
# [32]	validation_0-mlogloss:0.64611
# [33]	validation_0-mlogloss:0.64241
# [34]	validation_0-mlogloss:0.63890
# [35]	validation_0-mlogloss:0.63552
# [36]	validation_0-mlogloss:0.63233
# [37]	validation_0-mlogloss:0.62925
# [38]	validation_0-mlogloss:0.62624
# [39]	validation_0-mlogloss:0.62333
# [40]	validation_0-mlogloss:0.62064
# [41]	validation_0-mlogloss:0.61810
# [42]	validation_0-mlogloss:0.61557
# [43]	validation_0-mlogloss:0.61325
# [44]	validation_0-mlogloss:0.61096
# [45]	validation_0-mlogloss:0.60880
# [46]	validation_0-mlogloss:0.60670
# [47]	validation_0-mlogloss:0.60470
# [48]	validation_0-mlogloss:0.60279
# [49]	validation_0-mlogloss:0.60099
# [50]	validation_0-mlogloss:0.59922
# [51]	validation_0-mlogloss:0.59753
# [52]	validation_0-mlogloss:0.59591
# [53]	validation_0-mlogloss:0.59436
# [54]	validation_0-mlogloss:0.59286
# [55]	validation_0-mlogloss:0.59140
# [56]	validation_0-mlogloss:0.58999
# [57]	validation_0-mlogloss:0.58866
# [58]	validation_0-mlogloss:0.58732
# [59]	validation_0-mlogloss:0.58609
# [60]	validation_0-mlogloss:0.58486
# [61]	validation_0-mlogloss:0.58369
# [62]	validation_0-mlogloss:0.58255
# [63]	validation_0-mlogloss:0.58142
# [64]	validation_0-mlogloss:0.58034
# [65]	validation_0-mlogloss:0.57928
# [66]	validation_0-mlogloss:0.57828
# [67]	validation_0-mlogloss:0.57732
# [68]	validation_0-mlogloss:0.57635
# [69]	validation_0-mlogloss:0.57545
# [70]	validation_0-mlogloss:0.57461
# [71]	validation_0-mlogloss:0.57376
# [72]	validation_0-mlogloss:0.57293
# [73]	validation_0-mlogloss:0.57214
# [74]	validation_0-mlogloss:0.57138
# [75]	validation_0-mlogloss:0.57065
# [76]	validation_0-mlogloss:0.56995
# [77]	validation_0-mlogloss:0.56925
# [78]	validation_0-mlogloss:0.56859
# [79]	validation_0-mlogloss:0.56793
# [80]	validation_0-mlogloss:0.56730
# [81]	validation_0-mlogloss:0.56668
# [82]	validation_0-mlogloss:0.56609
# [83]	validation_0-mlogloss:0.56549
# [84]	validation_0-mlogloss:0.56492
# [85]	validation_0-mlogloss:0.56438
# [86]	validation_0-mlogloss:0.56381
# [87]	validation_0-mlogloss:0.56331
# [88]	validation_0-mlogloss:0.56281
# [89]	validation_0-mlogloss:0.56233
# [90]	validation_0-mlogloss:0.56185
# [91]	validation_0-mlogloss:0.56138
# [92]	validation_0-mlogloss:0.56094
# [93]	validation_0-mlogloss:0.56053
# [94]	validation_0-mlogloss:0.56010
# [95]	validation_0-mlogloss:0.55970
# [96]	validation_0-mlogloss:0.55932
# [97]	validation_0-mlogloss:0.55892
# [98]	validation_0-mlogloss:0.55856
# [99]	validation_0-mlogloss:0.55819
# [100]	validation_0-mlogloss:0.55785
# [101]	validation_0-mlogloss:0.55750
# [102]	validation_0-mlogloss:0.55717
# [103]	validation_0-mlogloss:0.55684
# [104]	validation_0-mlogloss:0.55653
# [105]	validation_0-mlogloss:0.55621
# [106]	validation_0-mlogloss:0.55590
# [107]	validation_0-mlogloss:0.55562
# [108]	validation_0-mlogloss:0.55533
# [109]	validation_0-mlogloss:0.55504
# [110]	validation_0-mlogloss:0.55478
# [111]	validation_0-mlogloss:0.55454
# [112]	validation_0-mlogloss:0.55426
# [113]	validation_0-mlogloss:0.55400
# [114]	validation_0-mlogloss:0.55376
# [115]	validation_0-mlogloss:0.55351
# [116]	validation_0-mlogloss:0.55329
# [117]	validation_0-mlogloss:0.55305
# [118]	validation_0-mlogloss:0.55283
# [119]	validation_0-mlogloss:0.55259
# [120]	validation_0-mlogloss:0.55237
# [121]	validation_0-mlogloss:0.55213
# [122]	validation_0-mlogloss:0.55192
# [123]	validation_0-mlogloss:0.55172
# [124]	validation_0-mlogloss:0.55151
# [125]	validation_0-mlogloss:0.55129
# [126]	validation_0-mlogloss:0.55109
# [127]	validation_0-mlogloss:0.55089
# [128]	validation_0-mlogloss:0.55068
# [129]	validation_0-mlogloss:0.55049
# [130]	validation_0-mlogloss:0.55032
# [131]	validation_0-mlogloss:0.55016
# [132]	validation_0-mlogloss:0.54997
# [133]	validation_0-mlogloss:0.54979
# [134]	validation_0-mlogloss:0.54963
# [135]	validation_0-mlogloss:0.54947
# [136]	validation_0-mlogloss:0.54932
# [137]	validation_0-mlogloss:0.54918
# [138]	validation_0-mlogloss:0.54902
# [139]	validation_0-mlogloss:0.54887
# [140]	validation_0-mlogloss:0.54873
# [141]	validation_0-mlogloss:0.54857
# [142]	validation_0-mlogloss:0.54843
# [143]	validation_0-mlogloss:0.54825
# [144]	validation_0-mlogloss:0.54813
# [145]	validation_0-mlogloss:0.54800
# [146]	validation_0-mlogloss:0.54785
# [147]	validation_0-mlogloss:0.54770
# [148]	validation_0-mlogloss:0.54756
# [149]	validation_0-mlogloss:0.54743
# [150]	validation_0-mlogloss:0.54729
# [151]	validation_0-mlogloss:0.54717
# [152]	validation_0-mlogloss:0.54705
# [153]	validation_0-mlogloss:0.54691
# [154]	validation_0-mlogloss:0.54679
# [155]	validation_0-mlogloss:0.54667
# [156]	validation_0-mlogloss:0.54657
# [157]	validation_0-mlogloss:0.54645
# [158]	validation_0-mlogloss:0.54632
# [159]	validation_0-mlogloss:0.54621
# [160]	validation_0-mlogloss:0.54612
# [161]	validation_0-mlogloss:0.54601
# [162]	validation_0-mlogloss:0.54591
# [163]	validation_0-mlogloss:0.54578
# [164]	validation_0-mlogloss:0.54566
# [165]	validation_0-mlogloss:0.54556
# [166]	validation_0-mlogloss:0.54547
# [167]	validation_0-mlogloss:0.54536
# [168]	validation_0-mlogloss:0.54528
# [169]	validation_0-mlogloss:0.54517
# [170]	validation_0-mlogloss:0.54507
# [171]	validation_0-mlogloss:0.54498
# [172]	validation_0-mlogloss:0.54489
# [173]	validation_0-mlogloss:0.54479
# [174]	validation_0-mlogloss:0.54470
# [175]	validation_0-mlogloss:0.54463
# [176]	validation_0-mlogloss:0.54453
# [177]	validation_0-mlogloss:0.54447
# [178]	validation_0-mlogloss:0.54439
# [179]	validation_0-mlogloss:0.54432
# [180]	validation_0-mlogloss:0.54426
# [181]	validation_0-mlogloss:0.54419
# [182]	validation_0-mlogloss:0.54412
# [183]	validation_0-mlogloss:0.54406
# [184]	validation_0-mlogloss:0.54397
# [185]	validation_0-mlogloss:0.54387
# [186]	validation_0-mlogloss:0.54382
# [187]	validation_0-mlogloss:0.54373
# [188]	validation_0-mlogloss:0.54365
# [189]	validation_0-mlogloss:0.54358
# [190]	validation_0-mlogloss:0.54353
# [191]	validation_0-mlogloss:0.54347
# [192]	validation_0-mlogloss:0.54340
# [193]	validation_0-mlogloss:0.54333
# [194]	validation_0-mlogloss:0.54326
# [195]	validation_0-mlogloss:0.54318
# [196]	validation_0-mlogloss:0.54311
# [197]	validation_0-mlogloss:0.54304
# [198]	validation_0-mlogloss:0.54299
# [199]	validation_0-mlogloss:0.54293
# [200]	validation_0-mlogloss:0.54288
# [201]	validation_0-mlogloss:0.54281
# [202]	validation_0-mlogloss:0.54276
# [203]	validation_0-mlogloss:0.54270
# [204]	validation_0-mlogloss:0.54264
# [205]	validation_0-mlogloss:0.54258
# [206]	validation_0-mlogloss:0.54250
# [207]	validation_0-mlogloss:0.54245
# [208]	validation_0-mlogloss:0.54241
# [209]	validation_0-mlogloss:0.54235
# [210]	validation_0-mlogloss:0.54230
# [211]	validation_0-mlogloss:0.54225
# [212]	validation_0-mlogloss:0.54221
# [213]	validation_0-mlogloss:0.54216
# [214]	validation_0-mlogloss:0.54212
# [215]	validation_0-mlogloss:0.54207
# [216]	validation_0-mlogloss:0.54204
# [217]	validation_0-mlogloss:0.54201
# [218]	validation_0-mlogloss:0.54195
# [219]	validation_0-mlogloss:0.54188
# [220]	validation_0-mlogloss:0.54183
# [221]	validation_0-mlogloss:0.54178
# [222]	validation_0-mlogloss:0.54172
# [223]	validation_0-mlogloss:0.54169
# [224]	validation_0-mlogloss:0.54164
# [225]	validation_0-mlogloss:0.54160
# [226]	validation_0-mlogloss:0.54157
# [227]	validation_0-mlogloss:0.54153
# [228]	validation_0-mlogloss:0.54148
# [229]	validation_0-mlogloss:0.54144
# [230]	validation_0-mlogloss:0.54140
# [231]	validation_0-mlogloss:0.54136
# [232]	validation_0-mlogloss:0.54132
# [233]	validation_0-mlogloss:0.54128
# [234]	validation_0-mlogloss:0.54125
# [235]	validation_0-mlogloss:0.54122
# [236]	validation_0-mlogloss:0.54119
# [237]	validation_0-mlogloss:0.54117
# [238]	validation_0-mlogloss:0.54113
# [239]	validation_0-mlogloss:0.54109
# [240]	validation_0-mlogloss:0.54106
# [241]	validation_0-mlogloss:0.54103
# [242]	validation_0-mlogloss:0.54099
# [243]	validation_0-mlogloss:0.54097
# [244]	validation_0-mlogloss:0.54094
# [245]	validation_0-mlogloss:0.54089
# [246]	validation_0-mlogloss:0.54085
# [247]	validation_0-mlogloss:0.54081
# [248]	validation_0-mlogloss:0.54078
# [249]	validation_0-mlogloss:0.54074
# [250]	validation_0-mlogloss:0.54071
# [251]	validation_0-mlogloss:0.54069
# [252]	validation_0-mlogloss:0.54067
# [253]	validation_0-mlogloss:0.54065
# [254]	validation_0-mlogloss:0.54062
# [255]	validation_0-mlogloss:0.54059
# [256]	validation_0-mlogloss:0.54056
# [257]	validation_0-mlogloss:0.54051
# [258]	validation_0-mlogloss:0.54049
# [259]	validation_0-mlogloss:0.54046
# [260]	validation_0-mlogloss:0.54043
# [261]	validation_0-mlogloss:0.54040
# [262]	validation_0-mlogloss:0.54038
# [263]	validation_0-mlogloss:0.54034
# [264]	validation_0-mlogloss:0.54031
# [265]	validation_0-mlogloss:0.54027
# [266]	validation_0-mlogloss:0.54024
# [267]	validation_0-mlogloss:0.54022
# [268]	validation_0-mlogloss:0.54018
# [269]	validation_0-mlogloss:0.54014
# [270]	validation_0-mlogloss:0.54011
# [271]	validation_0-mlogloss:0.54009
# [272]	validation_0-mlogloss:0.54006
# [273]	validation_0-mlogloss:0.54001
# [274]	validation_0-mlogloss:0.53999
# [275]	validation_0-mlogloss:0.53995
# [276]	validation_0-mlogloss:0.53991
# [277]	validation_0-mlogloss:0.53989
# [278]	validation_0-mlogloss:0.53988
# [279]	validation_0-mlogloss:0.53985
# [280]	validation_0-mlogloss:0.53984
# [281]	validation_0-mlogloss:0.53981
# [282]	validation_0-mlogloss:0.53977
# [283]	validation_0-mlogloss:0.53973
# [284]	validation_0-mlogloss:0.53969
# [285]	validation_0-mlogloss:0.53967
# [286]	validation_0-mlogloss:0.53963
# [287]	validation_0-mlogloss:0.53961
# [288]	validation_0-mlogloss:0.53958
# [289]	validation_0-mlogloss:0.53955
# [290]	validation_0-mlogloss:0.53953
# [291]	validation_0-mlogloss:0.53951
# [292]	validation_0-mlogloss:0.53949
# [293]	validation_0-mlogloss:0.53947
# [294]	validation_0-mlogloss:0.53943
# [295]	validation_0-mlogloss:0.53941
# [296]	validation_0-mlogloss:0.53939
# [297]	validation_0-mlogloss:0.53936
# [298]	validation_0-mlogloss:0.53935
# [299]	validation_0-mlogloss:0.53932
# [300]	validation_0-mlogloss:0.53929
# [301]	validation_0-mlogloss:0.53929
# [302]	validation_0-mlogloss:0.53927
# [303]	validation_0-mlogloss:0.53924
# [304]	validation_0-mlogloss:0.53923
# [305]	validation_0-mlogloss:0.53920
# [306]	validation_0-mlogloss:0.53917
# [307]	validation_0-mlogloss:0.53915
# [308]	validation_0-mlogloss:0.53912
# [309]	validation_0-mlogloss:0.53911
# [310]	validation_0-mlogloss:0.53910
# [311]	validation_0-mlogloss:0.53907
# [312]	validation_0-mlogloss:0.53904
# [313]	validation_0-mlogloss:0.53903
# [314]	validation_0-mlogloss:0.53900
# [315]	validation_0-mlogloss:0.53897
# [316]	validation_0-mlogloss:0.53894
# [317]	validation_0-mlogloss:0.53893
# [318]	validation_0-mlogloss:0.53889
# [319]	validation_0-mlogloss:0.53888
# [320]	validation_0-mlogloss:0.53887
# [321]	validation_0-mlogloss:0.53883
# [322]	validation_0-mlogloss:0.53880
# [323]	validation_0-mlogloss:0.53878
# [324]	validation_0-mlogloss:0.53875
# [325]	validation_0-mlogloss:0.53873
# [326]	validation_0-mlogloss:0.53870
# [327]	validation_0-mlogloss:0.53868
# [328]	validation_0-mlogloss:0.53866
# [329]	validation_0-mlogloss:0.53863
# [330]	validation_0-mlogloss:0.53861
# [331]	validation_0-mlogloss:0.53859
# [332]	validation_0-mlogloss:0.53858
# [333]	validation_0-mlogloss:0.53857
# [334]	validation_0-mlogloss:0.53856
# [335]	validation_0-mlogloss:0.53854
# [336]	validation_0-mlogloss:0.53853
# [337]	validation_0-mlogloss:0.53852
# [338]	validation_0-mlogloss:0.53851
# [339]	validation_0-mlogloss:0.53850
# ...
# [56]	validation_0-mlogloss:0.59387
# [57]	validation_0-mlogloss:0.59252
# [58]	validation_0-mlogloss:0.59124
# [59]	validation_0-mlogloss:0.58996
# [60]	validation_0-mlogloss:0.58873
# [61]	validation_0-mlogloss:0.58761
# [62]	validation_0-mlogloss:0.58645
# [63]	validation_0-mlogloss:0.58533
# [64]	validation_0-mlogloss:0.58425
# [65]	validation_0-mlogloss:0.58322
# [66]	validation_0-mlogloss:0.58222
# [67]	validation_0-mlogloss:0.58127
# [68]	validation_0-mlogloss:0.58034
# [69]	validation_0-mlogloss:0.57944
# [70]	validation_0-mlogloss:0.57856
# [71]	validation_0-mlogloss:0.57771
# [72]	validation_0-mlogloss:0.57693
# [73]	validation_0-mlogloss:0.57616
# [74]	validation_0-mlogloss:0.57539
# [75]	validation_0-mlogloss:0.57465
# [76]	validation_0-mlogloss:0.57396
# [77]	validation_0-mlogloss:0.57330
# [78]	validation_0-mlogloss:0.57262
# [79]	validation_0-mlogloss:0.57195
# [80]	validation_0-mlogloss:0.57134
# [81]	validation_0-mlogloss:0.57072
# [82]	validation_0-mlogloss:0.57012
# [83]	validation_0-mlogloss:0.56951
# [84]	validation_0-mlogloss:0.56896
# [85]	validation_0-mlogloss:0.56842
# [86]	validation_0-mlogloss:0.56789
# [87]	validation_0-mlogloss:0.56738
# [88]	validation_0-mlogloss:0.56690
# [89]	validation_0-mlogloss:0.56642
# [90]	validation_0-mlogloss:0.56597
# [91]	validation_0-mlogloss:0.56553
# [92]	validation_0-mlogloss:0.56510
# [93]	validation_0-mlogloss:0.56469
# [94]	validation_0-mlogloss:0.56431
# [95]	validation_0-mlogloss:0.56390
# [96]	validation_0-mlogloss:0.56349
# [97]	validation_0-mlogloss:0.56313
# [98]	validation_0-mlogloss:0.56274
# [99]	validation_0-mlogloss:0.56237
# [100]	validation_0-mlogloss:0.56202
# [101]	validation_0-mlogloss:0.56170
# [102]	validation_0-mlogloss:0.56135
# [103]	validation_0-mlogloss:0.56102
# [104]	validation_0-mlogloss:0.56071
# [105]	validation_0-mlogloss:0.56039
# [106]	validation_0-mlogloss:0.56009
# [107]	validation_0-mlogloss:0.55980
# [108]	validation_0-mlogloss:0.55955
# [109]	validation_0-mlogloss:0.55926
# [110]	validation_0-mlogloss:0.55895
# [111]	validation_0-mlogloss:0.55871
# [112]	validation_0-mlogloss:0.55846
# [113]	validation_0-mlogloss:0.55820
# [114]	validation_0-mlogloss:0.55795
# [115]	validation_0-mlogloss:0.55770
# [116]	validation_0-mlogloss:0.55745
# [117]	validation_0-mlogloss:0.55724
# [118]	validation_0-mlogloss:0.55702
# [119]	validation_0-mlogloss:0.55681
# [120]	validation_0-mlogloss:0.55660
# [121]	validation_0-mlogloss:0.55640
# [122]	validation_0-mlogloss:0.55621
# [123]	validation_0-mlogloss:0.55599
# [124]	validation_0-mlogloss:0.55578
# [125]	validation_0-mlogloss:0.55559
# [126]	validation_0-mlogloss:0.55542
# [127]	validation_0-mlogloss:0.55524
# [128]	validation_0-mlogloss:0.55506
# [129]	validation_0-mlogloss:0.55487
# [130]	validation_0-mlogloss:0.55471
# [131]	validation_0-mlogloss:0.55455
# [132]	validation_0-mlogloss:0.55439
# [133]	validation_0-mlogloss:0.55421
# [134]	validation_0-mlogloss:0.55406
# [135]	validation_0-mlogloss:0.55389
# [136]	validation_0-mlogloss:0.55376
# [137]	validation_0-mlogloss:0.55364
# [138]	validation_0-mlogloss:0.55345
# [139]	validation_0-mlogloss:0.55334
# [140]	validation_0-mlogloss:0.55317
# [141]	validation_0-mlogloss:0.55301
# [142]	validation_0-mlogloss:0.55286
# [143]	validation_0-mlogloss:0.55275
# [144]	validation_0-mlogloss:0.55262
# [145]	validation_0-mlogloss:0.55250
# [146]	validation_0-mlogloss:0.55237
# [147]	validation_0-mlogloss:0.55224
# [148]	validation_0-mlogloss:0.55212
# [149]	validation_0-mlogloss:0.55201
# [150]	validation_0-mlogloss:0.55189
# [151]	validation_0-mlogloss:0.55178
# [152]	validation_0-mlogloss:0.55166
# [153]	validation_0-mlogloss:0.55156
# [154]	validation_0-mlogloss:0.55144
# [155]	validation_0-mlogloss:0.55133
# [156]	validation_0-mlogloss:0.55120
# [157]	validation_0-mlogloss:0.55107
# [158]	validation_0-mlogloss:0.55094
# [159]	validation_0-mlogloss:0.55086
# [160]	validation_0-mlogloss:0.55072
# [161]	validation_0-mlogloss:0.55063
# [162]	validation_0-mlogloss:0.55053
# [163]	validation_0-mlogloss:0.55045
# [164]	validation_0-mlogloss:0.55035
# [165]	validation_0-mlogloss:0.55028
# [166]	validation_0-mlogloss:0.55020
# [167]	validation_0-mlogloss:0.55008
# [168]	validation_0-mlogloss:0.54997
# [169]	validation_0-mlogloss:0.54986
# [170]	validation_0-mlogloss:0.54978
# [171]	validation_0-mlogloss:0.54968
# [172]	validation_0-mlogloss:0.54960
# [173]	validation_0-mlogloss:0.54951
# [174]	validation_0-mlogloss:0.54943
# [175]	validation_0-mlogloss:0.54932
# [176]	validation_0-mlogloss:0.54926
# [177]	validation_0-mlogloss:0.54919
# [178]	validation_0-mlogloss:0.54910
# [179]	validation_0-mlogloss:0.54901
# [180]	validation_0-mlogloss:0.54890
# [181]	validation_0-mlogloss:0.54881
# [182]	validation_0-mlogloss:0.54875
# [183]	validation_0-mlogloss:0.54868
# [184]	validation_0-mlogloss:0.54861
# [185]	validation_0-mlogloss:0.54855
# [186]	validation_0-mlogloss:0.54848
# [187]	validation_0-mlogloss:0.54842
# [188]	validation_0-mlogloss:0.54835
# [189]	validation_0-mlogloss:0.54828
# [190]	validation_0-mlogloss:0.54821
# [191]	validation_0-mlogloss:0.54814
# [192]	validation_0-mlogloss:0.54807
# [193]	validation_0-mlogloss:0.54798
# [194]	validation_0-mlogloss:0.54791
# [195]	validation_0-mlogloss:0.54784
# [196]	validation_0-mlogloss:0.54777
# [197]	validation_0-mlogloss:0.54770
# [198]	validation_0-mlogloss:0.54764
# [199]	validation_0-mlogloss:0.54758
# [200]	validation_0-mlogloss:0.54750
# [201]	validation_0-mlogloss:0.54745
# [202]	validation_0-mlogloss:0.54739
# [203]	validation_0-mlogloss:0.54733
# [204]	validation_0-mlogloss:0.54727
# [205]	validation_0-mlogloss:0.54719
# [206]	validation_0-mlogloss:0.54714
# [207]	validation_0-mlogloss:0.54709
# [208]	validation_0-mlogloss:0.54705
# [209]	validation_0-mlogloss:0.54698
# [210]	validation_0-mlogloss:0.54692
# [211]	validation_0-mlogloss:0.54686
# [212]	validation_0-mlogloss:0.54679
# [213]	validation_0-mlogloss:0.54673
# [214]	validation_0-mlogloss:0.54667
# [215]	validation_0-mlogloss:0.54661
# [216]	validation_0-mlogloss:0.54656
# [217]	validation_0-mlogloss:0.54649
# [218]	validation_0-mlogloss:0.54643
# [219]	validation_0-mlogloss:0.54637
# [220]	validation_0-mlogloss:0.54633
# [221]	validation_0-mlogloss:0.54628
# [222]	validation_0-mlogloss:0.54624
# [223]	validation_0-mlogloss:0.54618
# [224]	validation_0-mlogloss:0.54612
# [225]	validation_0-mlogloss:0.54608
# [226]	validation_0-mlogloss:0.54603
# [227]	validation_0-mlogloss:0.54599
# [228]	validation_0-mlogloss:0.54591
# [229]	validation_0-mlogloss:0.54585
# [230]	validation_0-mlogloss:0.54581
# [231]	validation_0-mlogloss:0.54577
# [232]	validation_0-mlogloss:0.54573
# [233]	validation_0-mlogloss:0.54568
# [234]	validation_0-mlogloss:0.54562
# [235]	validation_0-mlogloss:0.54557
# [236]	validation_0-mlogloss:0.54553
# [237]	validation_0-mlogloss:0.54549
# [238]	validation_0-mlogloss:0.54545
# [239]	validation_0-mlogloss:0.54541
# [240]	validation_0-mlogloss:0.54536
# [241]	validation_0-mlogloss:0.54532
# [242]	validation_0-mlogloss:0.54528
# [243]	validation_0-mlogloss:0.54524
# [244]	validation_0-mlogloss:0.54520
# [245]	validation_0-mlogloss:0.54519
# [246]	validation_0-mlogloss:0.54513
# [247]	validation_0-mlogloss:0.54508
# [248]	validation_0-mlogloss:0.54504
# [249]	validation_0-mlogloss:0.54503
# [250]	validation_0-mlogloss:0.54498
# [251]	validation_0-mlogloss:0.54494
# [252]	validation_0-mlogloss:0.54489
# [253]	validation_0-mlogloss:0.54484
# [254]	validation_0-mlogloss:0.54479
# [255]	validation_0-mlogloss:0.54477
# [256]	validation_0-mlogloss:0.54472
# [257]	validation_0-mlogloss:0.54469
# [258]	validation_0-mlogloss:0.54463
# [259]	validation_0-mlogloss:0.54460
# [260]	validation_0-mlogloss:0.54458
# [261]	validation_0-mlogloss:0.54453
# [262]	validation_0-mlogloss:0.54451
# [263]	validation_0-mlogloss:0.54446
# [264]	validation_0-mlogloss:0.54442
# [265]	validation_0-mlogloss:0.54438
# [266]	validation_0-mlogloss:0.54435
# [267]	validation_0-mlogloss:0.54428
# [268]	validation_0-mlogloss:0.54424
# [269]	validation_0-mlogloss:0.54422
# [270]	validation_0-mlogloss:0.54420
# [271]	validation_0-mlogloss:0.54417
# [272]	validation_0-mlogloss:0.54412
# [273]	validation_0-mlogloss:0.54408
# [274]	validation_0-mlogloss:0.54404
# [275]	validation_0-mlogloss:0.54401
# [276]	validation_0-mlogloss:0.54398
# [277]	validation_0-mlogloss:0.54395
# [278]	validation_0-mlogloss:0.54391
# [279]	validation_0-mlogloss:0.54385
# [280]	validation_0-mlogloss:0.54382
# [281]	validation_0-mlogloss:0.54377
# [282]	validation_0-mlogloss:0.54372
# [283]	validation_0-mlogloss:0.54368
# [284]	validation_0-mlogloss:0.54363
# [285]	validation_0-mlogloss:0.54360
# [286]	validation_0-mlogloss:0.54357
# [287]	validation_0-mlogloss:0.54354
# [288]	validation_0-mlogloss:0.54351
# [289]	validation_0-mlogloss:0.54350
# [290]	validation_0-mlogloss:0.54348
# [291]	validation_0-mlogloss:0.54346
# [292]	validation_0-mlogloss:0.54344
# [293]	validation_0-mlogloss:0.54340
# [294]	validation_0-mlogloss:0.54338
# [295]	validation_0-mlogloss:0.54335
# [296]	validation_0-mlogloss:0.54331
# [297]	validation_0-mlogloss:0.54330
# [298]	validation_0-mlogloss:0.54328
# [299]	validation_0-mlogloss:0.54324
# [300]	validation_0-mlogloss:0.54321
# [301]	validation_0-mlogloss:0.54319
# [302]	validation_0-mlogloss:0.54316
# [303]	validation_0-mlogloss:0.54314
# [304]	validation_0-mlogloss:0.54314
# [305]	validation_0-mlogloss:0.54312
# [306]	validation_0-mlogloss:0.54308
# [307]	validation_0-mlogloss:0.54304
# [308]	validation_0-mlogloss:0.54301
# [309]	validation_0-mlogloss:0.54297
# [310]	validation_0-mlogloss:0.54295
# [311]	validation_0-mlogloss:0.54293
# [312]	validation_0-mlogloss:0.54290
# [313]	validation_0-mlogloss:0.54288
# [314]	validation_0-mlogloss:0.54286
# [315]	validation_0-mlogloss:0.54285
# [316]	validation_0-mlogloss:0.54282
# [317]	validation_0-mlogloss:0.54280
# [318]	validation_0-mlogloss:0.54279
# [319]	validation_0-mlogloss:0.54277
# [320]	validation_0-mlogloss:0.54275
# [321]	validation_0-mlogloss:0.54273
# [322]	validation_0-mlogloss:0.54270
# [323]	validation_0-mlogloss:0.54268
# [324]	validation_0-mlogloss:0.54266
# [325]	validation_0-mlogloss:0.54265
# [326]	validation_0-mlogloss:0.54262
# [327]	validation_0-mlogloss:0.54259
# [328]	validation_0-mlogloss:0.54258
# [329]	validation_0-mlogloss:0.54255
# [330]	validation_0-mlogloss:0.54252
# [331]	validation_0-mlogloss:0.54249
# [332]	validation_0-mlogloss:0.54246
# [333]	validation_0-mlogloss:0.54244
# [334]	validation_0-mlogloss:0.54242
# [335]	validation_0-mlogloss:0.54239
# [336]	validation_0-mlogloss:0.54238
# [337]	validation_0-mlogloss:0.54234
# [338]	validation_0-mlogloss:0.54233
# [339]	validation_0-mlogloss:0.54233
# [340]	validation_0-mlogloss:0.54230
# [341]	validation_0-mlogloss:0.54228
# [342]	validation_0-mlogloss:0.54226
# [343]	validation_0-mlogloss:0.54224
# [344]	validation_0-mlogloss:0.54222
# [345]	validation_0-mlogloss:0.54221
# [346]	validation_0-mlogloss:0.54219
# [347]	validation_0-mlogloss:0.54218
# [348]	validation_0-mlogloss:0.54217
# [349]	validation_0-mlogloss:0.54215
# [350]	validation_0-mlogloss:0.54214
# [351]	validation_0-mlogloss:0.54211
# [352]	validation_0-mlogloss:0.54210
# [353]	validation_0-mlogloss:0.54208
# [354]	validation_0-mlogloss:0.54206
# [355]	validation_0-mlogloss:0.54203
# [356]	validation_0-mlogloss:0.54202
# [357]	validation_0-mlogloss:0.54202
# [358]	validation_0-mlogloss:0.54200
# [359]	validation_0-mlogloss:0.54198
# [360]	validation_0-mlogloss:0.54196
# [361]	validation_0-mlogloss:0.54193
# [362]	validation_0-mlogloss:0.54191
# [363]	validation_0-mlogloss:0.54190
# [364]	validation_0-mlogloss:0.54189
# [365]	validation_0-mlogloss:0.54188
# [366]	validation_0-mlogloss:0.54186
# [367]	validation_0-mlogloss:0.54185
# [368]	validation_0-mlogloss:0.54184
# [369]	validation_0-mlogloss:0.54183
# [370]	validation_0-mlogloss:0.54180
# [371]	validation_0-mlogloss:0.54177
# [372]	validation_0-mlogloss:0.54176
# [373]	validation_0-mlogloss:0.54174
# [374]	validation_0-mlogloss:0.54173
# [375]	validation_0-mlogloss:0.54171
# [376]	validation_0-mlogloss:0.54169
# [377]	validation_0-mlogloss:0.54166
# [378]	validation_0-mlogloss:0.54163
# [379]	validation_0-mlogloss:0.54162
# [380]	validation_0-mlogloss:0.54161
# [381]	validation_0-mlogloss:0.54160
# [382]	validation_0-mlogloss:0.54158
# [383]	validation_0-mlogloss:0.54156
# [384]	validation_0-mlogloss:0.54155
# [385]	validation_0-mlogloss:0.54154
# [386]	validation_0-mlogloss:0.54153
# [387]	validation_0-mlogloss:0.54152
# [388]	validation_0-mlogloss:0.54149
# [389]	validation_0-mlogloss:0.54148
# [390]	validation_0-mlogloss:0.54146
# [391]	validation_0-mlogloss:0.54145
# [392]	validation_0-mlogloss:0.54144
# [393]	validation_0-mlogloss:0.54142
# [394]	validation_0-mlogloss:0.54140
# [395]	validation_0-mlogloss:0.54139
# [396]	validation_0-mlogloss:0.54137
# [397]	validation_0-mlogloss:0.54136
# [398]	validation_0-mlogloss:0.54135
# [399]	validation_0-mlogloss:0.54134
# [400]	validation_0-mlogloss:0.54133
# [401]	validation_0-mlogloss:0.54131
# [402]	validation_0-mlogloss:0.54129
# [403]	validation_0-mlogloss:0.54128
# [404]	validation_0-mlogloss:0.54126
# [405]	validation_0-mlogloss:0.54126
# [406]	validation_0-mlogloss:0.54125
# [407]	validation_0-mlogloss:0.54122
# [408]	validation_0-mlogloss:0.54120
# [409]	validation_0-mlogloss:0.54118
# [410]	validation_0-mlogloss:0.54116
# [411]	validation_0-mlogloss:0.54115
# [412]	validation_0-mlogloss:0.54114
# [413]	validation_0-mlogloss:0.54113
# [414]	validation_0-mlogloss:0.54112
# [415]	validation_0-mlogloss:0.54110
# [416]	validation_0-mlogloss:0.54108
# [417]	validation_0-mlogloss:0.54106
# [418]	validation_0-mlogloss:0.54105
# [419]	validation_0-mlogloss:0.54103
# [420]	validation_0-mlogloss:0.54100
# [421]	validation_0-mlogloss:0.54099
# [422]	validation_0-mlogloss:0.54098
# [423]	validation_0-mlogloss:0.54097
# [424]	validation_0-mlogloss:0.54096
# [425]	validation_0-mlogloss:0.54095
# [426]	validation_0-mlogloss:0.54095
# [427]	validation_0-mlogloss:0.54093
# [428]	validation_0-mlogloss:0.54092
# [429]	validation_0-mlogloss:0.54091
# [430]	validation_0-mlogloss:0.54090
# [431]	validation_0-mlogloss:0.54089
# [432]	validation_0-mlogloss:0.54089
# [433]	validation_0-mlogloss:0.54087
# [434]	validation_0-mlogloss:0.54086
# [435]	validation_0-mlogloss:0.54085
# [436]	validation_0-mlogloss:0.54084
# [437]	validation_0-mlogloss:0.54082
# [438]	validation_0-mlogloss:0.54081
# [439]	validation_0-mlogloss:0.54078
# [440]	validation_0-mlogloss:0.54077
# [441]	validation_0-mlogloss:0.54076
# [442]	validation_0-mlogloss:0.54073
# [443]	validation_0-mlogloss:0.54072
# [444]	validation_0-mlogloss:0.54072
# [445]	validation_0-mlogloss:0.54071
# [446]	validation_0-mlogloss:0.54070
# [447]	validation_0-mlogloss:0.54069
# [448]	validation_0-mlogloss:0.54068
# [449]	validation_0-mlogloss:0.54068
# [450]	validation_0-mlogloss:0.54066
# [451]	validation_0-mlogloss:0.54065
# [452]	validation_0-mlogloss:0.54065
# [453]	validation_0-mlogloss:0.54065
# [454]	validation_0-mlogloss:0.54065
# [455]	validation_0-mlogloss:0.54065
# [456]	validation_0-mlogloss:0.54064
# [457]	validation_0-mlogloss:0.54063
# [458]	validation_0-mlogloss:0.54062
# [459]	validation_0-mlogloss:0.54063
# [460]	validation_0-mlogloss:0.54061
# [461]	validation_0-mlogloss:0.54060
# [462]	validation_0-mlogloss:0.54058
# [463]	validation_0-mlogloss:0.54058
# [464]	validation_0-mlogloss:0.54057
# [465]	validation_0-mlogloss:0.54056
# [466]	validation_0-mlogloss:0.54055
# [467]	validation_0-mlogloss:0.54054
# [468]	validation_0-mlogloss:0.54054
# [469]	validation_0-mlogloss:0.54053
# [470]	validation_0-mlogloss:0.54052
# [471]	validation_0-mlogloss:0.54052
# [472]	validation_0-mlogloss:0.54051
# [473]	validation_0-mlogloss:0.54050
# [474]	validation_0-mlogloss:0.54049
# [475]	validation_0-mlogloss:0.54049
# [476]	validation_0-mlogloss:0.54049
# [477]	validation_0-mlogloss:0.54047
# [478]	validation_0-mlogloss:0.54046
# [479]	validation_0-mlogloss:0.54046
# [480]	validation_0-mlogloss:0.54045
# [481]	validation_0-mlogloss:0.54045
# [482]	validation_0-mlogloss:0.54043
# [483]	validation_0-mlogloss:0.54041
# [484]	validation_0-mlogloss:0.54040
# [485]	validation_0-mlogloss:0.54039
# [486]	validation_0-mlogloss:0.54039
# [487]	validation_0-mlogloss:0.54038
# [488]	validation_0-mlogloss:0.54036
# [489]	validation_0-mlogloss:0.54036
# [490]	validation_0-mlogloss:0.54036
# [491]	validation_0-mlogloss:0.54036
# [492]	validation_0-mlogloss:0.54035
# [493]	validation_0-mlogloss:0.54035
# [494]	validation_0-mlogloss:0.54033
# [495]	validation_0-mlogloss:0.54032
# [496]	validation_0-mlogloss:0.54031
# [497]	validation_0-mlogloss:0.54031
# [498]	validation_0-mlogloss:0.54029
# [499]	validation_0-mlogloss:0.54029
# [Fold 5/5] Best Score: 0.5403

# %%
xgb_ensemble.eval()
# Out:
# XGBoost K-Fold CV Micro F1 Score: 0.75581
# 0.755814444303744

# %%
# save models
with open("xgb_ensemble.pkl", "wb") as f:
    pickle.dump(xgb_ensemble, f)

# %%
# load models
with open("xgb_ensemble.pkl", "rb") as f:
    xgb_ensemble = pickle.load(f)

print(f"모델 개수: {len(xgb_ensemble.models)}")
print(f"모델 타입: {type(xgb_ensemble.models[0])}")
# Out:
# 모델 개수: 5
# 모델 타입: <class 'xgboost.sklearn.XGBClassifier'>

# %%
'''
from model import LightGBMLimit

lgb_limit = LightGBMLimit(df=final_train_df, target_col="damage_grade")
lgb_limit.encoding(categorical_cols=original_categorical_cols)
lgb_limit.kfold(n_splits=5)

lgb_limit.train()
lgb_limit.eval()

# save models
with open("lgb_limit.pkl", "wb") as f:
    pickle.dump(lgb_limit, f)
'''

# %%
final_categorical_cols = [
    "foundation_type",
    "roof_type",
    "ground_floor_type",
    "land_surface_condition",
    "other_floor_type",
    "position",
    "plan_configuration",
    "legal_ownership_status",
]

# %%
lgb_ensemble = LightGBM(df=final_train_df, target_col="damage_grade")
lgb_ensemble.encoding(categorical_cols=final_categorical_cols)
lgb_ensemble.kfold(n_splits=5)
train_columns = lgb_ensemble.X.columns.to_list()
"building_id" in train_columns, len(train_columns)
# Out:
# (False, 83)

# %%
lgb_ensemble.train()
# Out:
# 0it [00:00, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [678]	valid_0's multi_logloss: 0.55639
# 1it [00:19, 19.30s/it]
# [Fold 0] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [575]	valid_0's multi_logloss: 0.556535
# 2it [00:33, 16.35s/it]
# [Fold 1] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [641]	valid_0's multi_logloss: 0.553782
# 3it [00:49, 16.04s/it]
# [Fold 2] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [614]	valid_0's multi_logloss: 0.557798
# 4it [01:04, 15.63s/it]
# [Fold 3] done.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [574]	valid_0's multi_logloss: 0.558963
# 5it [01:18, 15.76s/it]
# [Fold 4] done.

# %%
lgb_ensemble.eval()
# Out:
# LightGBM Small Model CV Micro F1: 0.75256
# 0.7525604276269086

# %%
# save model
with open("lgb_ensemble.pkl", "wb") as f:
    pickle.dump(lgb_ensemble, f)

# %%
# load model
with open("lgb_ensemble.pkl", "rb") as f:
    lgb_ensemble = pickle.load(f)

print(f"모델 개수: {len(lgb_ensemble.models)}")
print(f"모델 타입: {type(lgb_ensemble.models[0])}")
# Out:
# 모델 개수: 5
# 모델 타입: <class 'lightgbm.sklearn.LGBMClassifier'>

# %% [markdown]
# # 5. Combining Baseline Models

# %% [markdown]
# - Ensemble Method를 사용해서 모델의 성능을 높인다.
# - Stacking 기법. LinearSVM을 이용해 Meta 모델을 만들기
# - TODO: lgb_ensemble + xgb_ensemble 모델 만들어보기

# %%
import torch
import pandas as pd

from prediction import predict_prob
from prediction import predict_lgb
from prediction import get_test_meta_data
from prediction import get_oof_predictions

from prediction import create_xgb_submission
from prediction import create_lgb_submission
from prediction import create_ensemble_submission

# %%
# 함수 실행
prob_df = predict_prob(
    lgb_models=lgb_ensemble.models,
    xgb_models=xgb_ensemble.models,
    test_df=train_values_embedded,
    categorical_cols=final_categorical_cols,
    train_cols=xgb_ensemble.X.columns.tolist(),
)

# 결과 확인
print(prob_df.shape)
prob_df.head()
# Out:
# (260601, 6)
#    lgb_class0  lgb_class1  lgb_class2  xgb_class0  xgb_class1  xgb_class2
# 0    0.002196    0.141024    0.856780    0.001845    0.105661    0.892493
# 1    0.004886    0.851847    0.143267    0.004857    0.849888    0.145255
# 2    0.005324    0.211425    0.783251    0.008953    0.257848    0.733199
# 3    0.002202    0.900890    0.096907    0.002520    0.900067    0.097413
# 4    0.001123    0.556464    0.442413    0.001170    0.540729    0.458101

# %%
# 1. 타겟 컬럼 이름 확인 (보통 'damage_grade' 혹은 'label' 입니다)
# train_labels_embedded의 컬럼을 확인해보세요. 보통 'building_id'와 'damage_grade'가 있을 겁니다.
target_col = 'damage_grade'

# 만약 컬럼명이 다르다면 아래 주석을 풀고 컬럼명을 확인 후 수정하세요
# print(train_labels_embedded.columns) 

# 2. building_id를 제외하고 타겟값만 넘겨주도록 수정
X_train_meta_df = get_oof_predictions(
    lgb_models=lgb_ensemble.models,
    xgb_models=xgb_ensemble.models,
    X=train_values_embedded,
    
    # [수정된 부분] 전체 DF 대신 특정 컬럼만 선택해서 넘깁니다.
    y=train_labels_embedded[target_col], 
    
    categorical_cols=final_categorical_cols,
    train_cols=xgb_ensemble.X.columns.tolist()
)

print("OOF Shape:", X_train_meta_df.shape)
# 이제 (260601, 6)이 정상적으로 출력될 것입니다.
# Out:
# Generating OOF Predictions...
# OOF Shape: (260601, 6)

# %%
y_train_tensor = train_labels_embedded['damage_grade'] - 1 
meta_model = train_stacking_model(X_train_meta_df, y_train_tensor, input_dim=6)

# %%
# 2-3. 테스트 데이터 메타 데이터 생성
X_test_meta, test_ids = get_test_meta_data(
    lgb_models=lgb_ensemble.models,
    xgb_models=xgb_ensemble.models,
    test_df=test_values_embedded,
    categorical_cols=final_categorical_cols,
    train_cols=xgb_ensemble.X.columns.tolist()
)

# %%
# 2-4. 최종 예측 수행
meta_model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    X_test_tensor = torch.FloatTensor(X_test_meta.values).to(device)
    outputs = meta_model(X_test_tensor)
    # Logits -> 확률 -> 가장 높은 클래스 선택
    # 0,1,2 로 나오므로 다시 +1 해서 1,2,3으로 복구
    final_preds = torch.argmax(outputs, dim=1).cpu().numpy() + 1 

# 2-5. 제출 파일 생성
submission = pd.DataFrame({
    'building_id': test_ids,
    'damage_grade': final_preds
})

print("최종 예측 완료!")
print(submission.head())

# 저장
submission.to_csv('submission_stacking_nn.csv', index=False)

# %% [markdown]
# # 6. Submission
# - 모델 예측 결과를 통해 최종 결과를 도출한다.

# %%
print("train feature count:", len(lgb_ensemble.X.columns.tolist()), len(xgb_ensemble.X.columns.tolist()))

# %%
lgb_ensemble.X.columns.tolist()
# Out:
# ['count_floors_pre_eq',
#  'age',
#  'area_percentage',
#  'height_percentage',
#  'land_surface_condition',
#  'foundation_type',
#  'roof_type',
#  'ground_floor_type',
#  'other_floor_type',
#  'position',
#  'plan_configuration',
#  'has_superstructure_adobe_mud',
#  'has_superstructure_mud_mortar_stone',
#  'has_superstructure_stone_flag',
#  'has_superstructure_cement_mortar_stone',
#  'has_superstructure_mud_mortar_brick',
#  'has_superstructure_cement_mortar_brick',
#  'has_superstructure_timber',
#  'has_superstructure_bamboo',
#  'has_superstructure_rc_non_engineered',
#  'has_superstructure_rc_engineered',
#  'has_superstructure_other',
#  'legal_ownership_status',
#  'count_families',
#  'has_secondary_use',
#  'has_secondary_use_agriculture',
#  'has_secondary_use_hotel',
#  'has_secondary_use_rental',
#  'has_secondary_use_institution',
#  'has_secondary_use_school',
#  'has_secondary_use_industry',
#  'has_secondary_use_health_post',
#  'has_secondary_use_gov_office',
#  'has_secondary_use_use_police',
#  'has_secondary_use_other',
#  'geo_emb_0',
#  'geo_emb_1',
#  'geo_emb_2',
#  'geo_emb_3',
#  'geo_emb_4',
#  'geo_emb_5',
#  'geo_emb_6',
#  'geo_emb_7',
#  'geo_emb_8',
#  'geo_emb_9',
#  'geo_emb_10',
#  'geo_emb_11',
#  'geo_emb_12',
#  'geo_emb_13',
#  'geo_emb_14',
#  'geo_emb_15',
#  'geo_emb_16',
#  'geo_emb_17',
#  'geo_emb_18',
#  'geo_emb_19',
#  'geo_emb_20',
#  'geo_emb_21',
#  'geo_emb_22',
#  'geo_emb_23',
#  'geo_emb_24',
#  'geo_emb_25',
#  'geo_emb_26',
#  'geo_emb_27',
#  'geo_emb_28',
#  'geo_emb_29',
#  'geo_emb_30',
#  'geo_emb_31',
#  'geo_emb2_0',
#  'geo_emb2_1',
#  'geo_emb2_2',
#  'geo_emb2_3',
#  'geo_emb2_4',
#  'geo_emb2_5',
#  'geo_emb2_6',
#  'geo_emb2_7',
#  'geo_emb2_8',
#  'geo_emb2_9',
#  'geo_emb2_10',
#  'geo_emb2_11',
#  'geo_emb2_12',
#  'geo_emb2_13',
#  'geo_emb2_14',
#  'geo_emb2_15']

# %%
xgb_ensemble.X.columns.tolist()

# %%
avg_test_probabilities = predict_lgb(
        models=models,
        test_df=test_df.drop(columns=['building_id']),
        categorical_cols=categorical_cols,
    )

# %% [markdown]
# ## 6-1. Single Model Submission

# %% [markdown]
# ### 6-1-1. LightGBM

# %%
lgb_submission_df = create_lgb_submission(
    models=lgb_ensemble.models,
    test_df=test_features_with_embeddings,
    test_building_ids=test_features_with_embeddings['building_id'], # 테스트셋 building_id 컬럼
    categorical_cols=final_categorical_cols
)

# 결과 확인
print(lgb_submission_df.head(5))
lgb_submission_df.to_csv("lgb_submission22.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 lgb_submission_df = create_lgb_submission(
#       2     models=lgb_ensemble.models,
# ----> 3     test_df=test_values_embedded,
#       4     test_building_ids=test_values_embedded['building_id'], # 테스트셋 building_id 컬럼
#       5     categorical_cols=final_categorical_cols
#       6 )
#       8 # 결과 확인
#       9 print(lgb_submission_df.head(5))
#
# NameError: name 'test_values_embedded' is not defined

# %% [markdown]
# ### 6-1-2. XGBoost

# %%
geo_cols = ['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id']
xgb_categorical_cols = [col for col in original_categorical_cols if col not in geo_cols]

xgb_submission_df = create_xgb_submission(
    models=xgb_ensemble.models,
    test_df=train_values_embedded,
    test_building_ids=train_values_embedded['building_id'], # 테스트셋 building_id 컬럼
    categorical_cols=xgb_categorical_cols,
    train_cols=xgb_ensemble.X.columns.tolist()
)

# 결과 확인
print(xgb_submission_df.head(5))
xgb_submission_df.to_csv("xgb_submission.csv", index=False)
# Out:
# 테스트 데이터 예측 확률 계산 중
# xgb submission: 260601개 예측 결과 생성됨
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             2

# %% [markdown]
# ## 6-2. Ensemble Model Submission

# %%
# LightGBM 60%, XGBoost 40% 의견반영
ensemble_submission_df = create_ensemble_submission(
    lgb_models=lgb_ensemble.models,
    xgb_models=xgb_ensemble.models,
    test_df=test_values_embedded,
    test_building_ids=test_values_embedded['building_id'],
    categorical_cols=final_categorical_cols,
    train_cols=xgb_ensemble.X.columns.tolist(),
    weights=(0.6, 0.4)
)

print(ensemble_submission_df.head(10))
ensemble_submission_df.to_csv("final_submission.csv", index=False)
# Out:
# xgb 테스트 데이터 예측 확률 계산 중
# lgb 테스트 데이터 예측 확률 계산 중
# 모델 결과 가중 합산 중
# ensemble submission: 86868개 예측 결과 생성됨
#    building_id  damage_grade
# 0       300051             3
# 1        99355             2
# 2       890251             3
# 3       745817             1
# 4       421793             3
# 5       871976             2
# 6       691228             2
# 7       896100             3
# 8       343471             2
# 9       766647             2
